# %% [markdown]
# # Key consideration
# Avoiding Filter Attributes: In all scripts, we initialize pybgpstream without using any filter attributes. All filtering (e.g., by prefix, ASN, or other criteria) is done within the main loop by checking each record and element.
#
# Processing within Main Loop: By iterating over every element, we ensure that we process all BGP updates and apply our custom logic directly within the loop.

# %% [markdown]
# # Counting Announcements and Withdrawals

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def count_announcements_withdrawals(from_time, until_time, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    announcements = defaultdict(int)
    withdrawals = defaultdict(int)

    for rec in stream.records():
        for elem in rec:
            elem_time = datetime.utcfromtimestamp(elem.time)
            peer_asn = elem.peer_asn
            prefix = elem.fields.get("prefix")

            if prefix is None:
                continue

            if elem.type == 'A':
                announcements[prefix] += 1
            elif elem.type == 'W':
                withdrawals[prefix] += 1

    print("Announcements:")
    for prefix, count in announcements.items():
        print(f"{prefix}: {count}")

    print("\nWithdrawals:")
    for prefix, count in withdrawals.items():
        print(f"{prefix}: {count}")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 00:05:00"
count_announcements_withdrawals(from_time, until_time)
# Out:
# Announcements:
# 130.137.111.0/24: 94
# 2a0e:9b43::/48: 817
# 102.69.52.0/22: 10
# 156.250.128.0/17: 3
# 2804:7160::/32: 161
# 55.58.238.0/24: 93
# 55.5.236.0/24: 77
# 67.211.53.0/24: 294
# 2a12:3fc2:8004::/46: 422
# 2a0e:b107:1d8::/46: 539
# 2a06:a005:554::/46: 433
# 2a10:cc45:625::/48: 18
# 2a10:cc45:7e0::/48: 14
# 2a10:cc45:438::/48: 13
# 2602:feda:bf0::/46: 447
# 202.45.88.0/24: 128
# 203.145.74.0/24: 128
# 203.145.78.0/24: 128
# 102.214.120.0/22: 1424
# 84.205.78.0/24: 32
# 2001:7fb:fe03::/48: 27
# 2001:7fb:fe01::/48: 22
# 2001:7fb:fe15::/48: 29
# 84.205.76.0/24: 37
# 84.205.67.0/24: 36
# 64.68.236.0/22: 149
# 84.205.79.0/24: 26
# 84.205.65.0/24: 19
# 58.147.189.0/24: 53
# 2001:7fb:fe18::/48: 23
# 2602:ffe4:c17::/48: 53
# 2604:3b80::/32: 85
# 168.196.156.0/24: 63
# 180.149.252.0/24: 28
# 180.149.253.0/24: 56
# 182.239.49.0/24: 28
# 182.239.53.0/24: 56
# 2606:7540:5::/48: 18
# 177.70.26.0/24: 27
# 113.20.140.0/24: 57
# 113.20.137.0/24: 57
# 113.20.136.0/24: 57
# 202.153.26.0/24: 57
# 202.153.23.0/24: 57
# 202.153.28.0/24: 57
# 202.153.17.0/24: 57
# 202.153.21.0/24: 57
# 202.153.20.0/24: 57
# 202.153.24.0/24: 57
# 202.153.19.0/24: 57
# 202.153.22.0/24: 57
# 202.153.31.0/24: 57
# 202.153.25.0/24: 57
# 202.153.16.0/24: 57
# 202.153.30.0/24: 57
# 202.153.18.0/24: 57
# 2001:df1:7840::/48: 133
# 178.22.141.0/24: 115
# 84.205.77.0/24: 32
# 104.247.89.0/24: 1
# 104.247.90.0/23: 1
# 104.129.160.0/21: 1
# 2804:6248::/32: 4
# 2a10:cc44:15f::/48: 11
# 191.243.136.0/22: 7
# 189.89.22.0/24: 43
# 189.89.17.0/24: 47
# 2001:7fb:fe0d::/48: 25
# 103.155.5.0/24: 98
# 2a10:cc45:444::/48: 2
# 2a10:cc45:79e::/48: 1
# 84.205.70.0/24: 38
# 2a02:16c8:6000::/35: 7
# 213.204.80.0/24: 6
# 213.204.79.0/24: 39
# 2a12:e341::/32: 119
# 147.112.0.0/16: 71
# 202.5.18.0/23: 1
# 202.5.20.0/22: 1
# 202.5.16.0/22: 1
# 2804:8134::/32: 5
# 2602:80c:f000::/44: 18
# 103.165.248.0/24: 72
# 2804:4358::/32: 9
# 2001:7fb:fe06::/48: 30
# 186.193.28.0/24: 43
# 93.170.35.0/24: 37
# 27.131.3.0/24: 344
# 2607:6b80:5d::/48: 3
# 2804:7f70::/32: 4
# 2404:b300:11::/48: 28
# 2404:b300:101::/48: 28
# 2404:b300:1::/48: 28
# 2404:b300:133::/48: 28
# 2404:b300:12::/48: 28
# 2404:b300:2::/48: 28
# 2404:b300:100::/48: 28
# 2602:fc24:13::/48: 122
# 91.202.0.0/22: 37
# 176.107.88.0/21: 35
# 195.137.244.0/23: 37
# 2607:f710:47::/48: 3
# 2607:f710:85::/48: 3
# 2607:f710:60::/48: 3
# 2607:f710:1000::/48: 3
# 2607:f710:35::/48: 3
# 45.83.89.0/24: 2
# 38.205.128.0/22: 2
# 2804:4ba4::/32: 2
# 186.250.248.0/23: 42
# 44.31.41.0/24: 42
# 2a13:4c00:18::/48: 19
# 2804:20fc:1b00::/48: 176
# 2a0a:6040:a450::/47: 17
# 63.251.221.0/24: 39
# 192.206.204.0/24: 1
# 185.228.169.0/24: 1
# 185.228.171.0/24: 1
# 2406:840:996f::/48: 18
# 2406:840:9967::/48: 18
# 2406:840:9966::/48: 18
# 68.68.97.0/24: 50
# 2401:ea00:25::/48: 41
# 2001:dc6::/32: 99
# 166.0.187.0/24: 1
# 2a0f:6580:e::/48: 43
# 2a0a:2f40::/32: 129
# 102.219.223.0/24: 3
# 2a0e:b107:1a38::/48: 16
# 38.107.164.0/23: 1
# 38.107.166.0/24: 1
# 2804:2000:3000::/36: 4
# 2a10:cbc0::/29: 190
# 178.250.1.0/24: 17
# 102.217.52.0/23: 47
# 74.123.96.0/24: 1
# 2804:8768::/32: 38
# 2a06:a005:1d57::/48: 13
# 216.71.103.0/24: 40
# 2a10:cc45:7ce::/48: 11
# 2a10:cc45:75a::/48: 6
# 2a10:cc45:6c9::/48: 10
# 2a10:cc45:69b::/48: 9
# 2a10:cc45:56e::/48: 10
# 2a10:cc45:5ca::/48: 14
# 2a10:cc45:5e2::/48: 14
# 2a10:cc45:68f::/48: 14
# 2804:64e4::/32: 4
# 179.127.24.0/24: 3
# 2606:2800:e004::/48: 67
# 146.71.80.0/22: 1
# 2a0c:da04:18::/48: 54
# 2402:cec0::/32: 25
# 2001:1380:2000::/36: 187
# 180.210.246.0/23: 1
# 2a06:8e40::/29: 4
# 138.118.239.0/24: 43
# 138.118.237.0/24: 48
# 185.92.230.0/23: 36
# 185.92.230.0/24: 15
# 176.124.58.0/24: 73
# 112.137.160.0/24: 18
# 2a0f:c440::/48: 5
# 191.37.24.0/24: 44
# 91.207.175.0/24: 1
# 38.95.111.0/24: 1
# 38.95.110.0/24: 1
# 37.120.132.0/24: 1
# 37.120.219.0/24: 1
# 2804:4e44::/32: 4
# 2a06:e881:5502::/48: 5
# 2602:fed2:7101::/48: 5
# 2a06:e881:5501::/48: 5
# 2602:fc52:315::/48: 5
# 84.205.82.0/24: 22
# 41.78.216.0/24: 16
# 116.206.96.0/24: 2
# 130.137.81.0/24: 28
# 177.190.215.0/24: 27
# 2a06:a005:550::/46: 274
# 177.70.28.0/24: 14
# 2804:12cc:8000::/33: 95
# 2804:12cc::/33: 95
# 2a06:3b80:22::/48: 3
# 2606:6200:1401::/48: 101
# 2.58.240.0/24: 1
# 44.31.85.0/24: 150
# 55.46.180.0/24: 7
# 55.46.178.0/24: 7
# 2001:4d8f::/32: 7
# 2604:a680:5::/48: 3
# 2804:5f90:8000::/33: 3
# 2804:5f90::/32: 3
# 2804:5f90::/33: 3
# 2001:4479:1900:b00::/56: 1
# 197.159.79.0/24: 4
# 197.159.72.0/24: 4
# 197.159.67.0/24: 4
# 41.222.209.0/24: 4
# 2001:7fb:fe13::/48: 26
# 128.201.183.0/24: 141
# 199.115.228.0/22: 1
# 185.205.180.0/22: 1
# 178.157.48.0/22: 1
# 184.170.208.0/20: 1
# 185.180.16.0/22: 1
# 176.122.160.0/19: 1
# 176.122.128.0/19: 1
# 172.96.16.0/22: 1
# 144.168.56.0/22: 1
# 144.168.60.0/22: 1
# 107.182.24.0/22: 1
# 107.182.16.0/22: 1
# 107.182.20.0/22: 1
# 107.182.28.0/22: 1
# 107.182.180.0/22: 1
# 107.182.184.0/21: 1
# 144.34.252.0/22: 1
# 138.128.192.0/20: 1
# 144.34.240.0/22: 1
# 144.34.232.0/22: 1
# 144.34.244.0/22: 1
# 144.34.224.0/22: 1
# 144.34.128.0/19: 1
# 144.34.192.0/19: 1
# 144.34.160.0/19: 1
# 138.128.220.0/22: 1
# 144.34.248.0/22: 1
# 144.34.236.0/22: 1
# 144.34.228.0/22: 1
# 104.36.64.0/21: 1
# 104.224.188.0/22: 1
# 104.224.184.0/22: 1
# 104.36.187.0/24: 1
# 104.243.16.0/22: 1
# 104.194.76.0/24: 1
# 104.224.176.0/22: 1
# 104.243.28.0/22: 1
# 104.225.232.0/21: 1
# 104.36.185.0/24: 1
# 104.243.24.0/22: 1
# 104.224.152.0/21: 1
# 104.194.78.0/23: 1
# 104.194.77.0/24: 1
# 104.128.84.0/22: 1
# 104.243.20.0/22: 1
# 104.225.144.0/20: 1
# 104.153.96.0/21: 1
# 104.160.40.0/21: 1
# 37.120.147.0/24: 2
# 37.120.150.0/24: 2
# 45.152.182.0/24: 2
# 82.102.29.0/24: 2
# 38.204.60.0/22: 2
# 38.95.109.0/24: 2
# 92.118.186.0/24: 2
# 38.203.128.0/22: 2
# 82.102.30.0/24: 2
# 83.143.247.0/24: 2
# 38.201.192.0/22: 2
# 37.120.214.0/24: 2
# 82.102.31.0/24: 2
# 45.83.186.0/23: 2
# 45.91.188.0/22: 2
# 69.51.31.0/24: 2
# 45.86.28.0/22: 2
# 45.130.33.0/24: 2
# 45.82.40.0/23: 2
# 45.130.66.0/23: 2
# 45.13.248.0/23: 2
# 80.76.52.0/22: 2
# 45.82.48.0/22: 2
# 103.129.118.0/24: 2
# 45.13.28.0/23: 2
# 83.150.220.0/22: 2
# 45.83.185.0/24: 2
# 2605:52c0:4000::/48: 18
# 2404:b300:23::/48: 28
# 2404:b300:32::/48: 28
# 2404:b300:31::/48: 28
# 2404:b300:33::/48: 28
# 2404:b300:10::/48: 28
# 2404:b300::/48: 28
# 2804:4170::/40: 4
# 2620:6e:a002::/48: 3
# 2620:12f:e000::/48: 18
# 2620:12f:e000::/40: 18
# 173.254.220.0/24: 1
# 175.110.106.0/24: 1
# 167.160.184.0/24: 1
# 167.160.180.0/24: 1
# 167.160.181.0/24: 1
# 175.110.104.0/24: 1
# 173.205.86.0/24: 1
# 107.161.95.0/24: 1
# 107.150.20.0/24: 1
# 103.185.98.0/23: 1
# 66.212.24.0/24: 1
# 66.212.18.0/24: 1
# 66.63.187.0/24: 1
# 67.215.255.0/24: 1
# 66.212.23.0/24: 1
# 2a0e:b107:a50::/44: 15
# 2a0e:b107:a51::/48: 15
# 2a0e:b107:a56::/48: 15
# 2a0e:b107:a57::/48: 15
# 2a0e:b107:a52::/48: 15
# 2a0e:b107:a50::/48: 15
# 2a0e:b107:a55::/48: 15
# 2a0e:b107:a54::/48: 15
# 2a0e:b107:a53::/48: 15
# 2804:218:7002::/48: 18
# 2804:218:7001::/48: 18
# 2804:218:7000::/48: 18
# 2a0c:7a80::/29: 34
# 2602:fcef::/36: 18
# 2605:dd40:5275::/48: 18
# 2605:dd40:5ccc::/48: 18
# 2605:dd40:5bbb::/48: 18
# 2605:dd40:8202::/48: 18
# 2602:fe12:1::/48: 18
# 92.119.163.0/24: 1
# 2.57.151.0/24: 1
# 2.56.139.0/24: 1
# 2620:6e:a003::/48: 8
# 2620:6e:a007::/48: 8
# 2602:fbaf:804::/48: 17
# 2602:fbaf:808::/47: 18
# 2602:fbaf:1::/48: 17
# 2602:fbaf:201::/48: 17
# 185.37.101.0/24: 25
# 23.236.73.0/24: 1
# 2602:fb67::/48: 18
# 2602:feda:bd0::/48: 15
# 170.130.204.0/22: 2
# 170.130.8.0/22: 2
# 170.130.32.0/22: 2
# 170.130.252.0/22: 2
# 170.130.100.0/22: 2
# 170.130.220.0/22: 2
# 170.130.104.0/22: 2
# 170.130.236.0/22: 2
# 170.130.184.0/22: 2
# 170.130.72.0/22: 2
# 170.130.156.0/22: 2
# 170.130.232.0/22: 2
# 170.130.116.0/22: 2
# 170.130.92.0/23: 1
# 173.232.196.0/22: 1
# 173.232.244.0/23: 1
# 173.232.84.0/22: 1
# 173.44.160.0/23: 1
# 173.232.100.0/22: 1
# 173.232.140.0/22: 1
# 173.232.176.0/22: 1
# 173.232.236.0/22: 1
# 173.232.36.0/23: 1
# 107.158.104.0/22: 1
# 107.158.188.0/22: 1
# 107.158.8.0/22: 1
# 104.206.164.0/22: 1
# 104.206.212.0/22: 1
# 107.158.192.0/22: 1
# 104.206.208.0/22: 1
# 104.140.220.0/22: 1
# 104.140.152.0/22: 1
# 104.140.204.0/22: 1
# 104.140.176.0/22: 1
# 104.140.92.0/22: 1
# 104.140.116.0/22: 1
# 104.140.172.0/22: 1
# 104.140.168.0/22: 1
# 50.3.40.0/22: 1
# 50.3.148.0/22: 1
# 50.3.52.0/22: 1
# 50.3.176.0/22: 1
# 50.2.244.0/22: 1
# 50.2.60.0/22: 1
# 50.2.32.0/22: 1
# 50.2.72.0/22: 1
# 50.3.252.0/22: 1
# 50.2.48.0/22: 1
# 50.3.168.0/22: 1
# 50.3.216.0/22: 1
# 50.2.180.0/22: 1
# 50.3.8.0/22: 1
# 50.3.112.0/22: 1
# 50.2.92.0/22: 1
# 50.2.68.0/22: 1
# 50.3.4.0/22: 1
# 50.2.76.0/22: 1
# 50.2.52.0/22: 1
# 50.3.108.0/22: 1
# 50.3.12.0/22: 1
# 50.2.248.0/22: 1
# 50.3.96.0/22: 1
# 50.3.128.0/22: 1
# 50.3.48.0/22: 1
# 50.3.24.0/22: 1
# 23.231.68.0/22: 1
# 23.90.20.0/22: 1
# 23.231.88.0/22: 1
# 23.90.28.0/22: 1
# 23.231.44.0/22: 1
# 23.231.76.0/22: 1
# 23.231.124.0/22: 1
# 23.90.18.0/23: 1
# 23.231.72.0/22: 1
# 23.231.80.0/22: 1
# 2804:2bb0:ff00::/40: 5
# 2a06:e881:2509::/48: 18
# 2a0f:85c1:31::/48: 3
# 2804:80c8::/32: 3
# 2605:d680::/32: 18
# 2804:4e4c:8000::/33: 4
# 2804:4e4c::/32: 4
# 2606:bdc0:5::/48: 23
# 2a0f:7d00:1::/48: 9
# 2602:fed2:770e::/48: 18
# 2602:ffc5:108::/48: 15
# 2606:bdc0:c0de::/48: 3
# 2606:11c0::/32: 3
# 160.119.69.0/24: 1
# 160.119.72.0/24: 1
# 160.119.66.0/24: 1
# 2804:4e04::/32: 4
# 170.247.156.0/24: 67
# 168.194.135.0/24: 68
# 2a0b:4340:22::/48: 18
# 172.225.237.0/24: 15
# 172.225.236.0/24: 15
# 172.224.75.0/24: 15
# 172.225.235.0/24: 15
# 150.242.91.0/24: 1
# 150.242.90.0/24: 1
# 104.36.186.0/24: 1
# 104.36.184.0/24: 1
# 104.194.80.0/20: 1
# 74.117.240.0/22: 8
# 2a06:e881:6600::/48: 18
# 103.196.36.0/24: 1
# 2804:4c1c::/32: 7
# 102.217.8.0/22: 3
# 2a07:aec0::/29: 18
# 103.196.148.0/22: 1
# 103.37.202.0/23: 1
# 94.156.168.0/23: 1
# 23.247.144.0/22: 1
# 2a0e:8f02:10f3::/48: 5
# 31.31.168.0/21: 1
# 2607:fcd0:1336::/47: 3
# 2001:678:d24::/48: 1
# 31.31.171.0/24: 1
# 91.92.67.0/24: 1
# 2001:a68::/32: 1
# 31.186.239.0/24: 1
# 168.176.213.0/24: 1
# 168.176.205.0/24: 1
# 2400:c540:52::/48: 3
# 2400:c540:53::/48: 3
# 2001:67c:2e4::/48: 1
# 194.69.160.0/24: 1
# 193.109.194.0/24: 1
# 193.109.199.0/24: 1
# 166.0.220.0/24: 1
# 163.5.188.0/24: 1
# 104.234.48.0/24: 1
# 87.254.29.0/24: 1
# 84.32.62.0/24: 1
# 84.32.83.0/24: 1
# 50.114.59.0/24: 1
# 50.114.83.0/24: 1
# 45.140.246.0/24: 1
# 62.182.173.0/24: 1
# 23.26.239.0/24: 1
# 2001:67c:1968::/48: 1
# 91.92.116.0/23: 1
# 91.92.118.0/23: 1
# 89.145.160.0/22: 1
# 91.92.224.0/23: 1
# 130.137.86.0/24: 5
# 107.161.48.0/23: 2
# 2001:67c:22e4::/48: 1
# 45.146.122.0/24: 2
# 2001:67c:1870::/48: 1
# 2001:678:302::/48: 1
# 2001:678:b68::/48: 1
# 2a01:130::/32: 1
# 2001:67c:6fc::/48: 1
# 2a00:1930::/32: 1
# 38.102.103.0/24: 30
# 38.117.91.0/24: 30
# 204.225.220.0/24: 30
# 2803:2200::/32: 1
# 37.252.212.0/23: 1
# 37.252.212.0/24: 1
# 198.168.5.0/24: 30
# 204.19.248.0/22: 30
# 38.20.183.0/24: 30
# 23.128.0.0/24: 30
# 64.191.32.0/20: 30
# 205.207.26.0/24: 30
# 216.162.224.0/20: 30
# 64.191.47.0/24: 30
# 204.19.252.0/23: 30
# 2604:1380:4090::/44: 1
# 2604:1380:ffc0::/44: 1
# 170.76.241.0/24: 30
# 2602:fb39:f00::/48: 1
# 2402:5c40:5c41::/48: 1
# 46.232.128.0/21: 1
# 206.130.179.0/24: 30
# 2800:5f0:82d::/48: 1
# 2800:5f0:80c::/48: 1
# 2800:5f0:2042::/48: 1
# 2800:5f0:2045::/48: 1
# 2800:5f0:6023::/48: 1
# 31.11.172.0/24: 1
# 37.8.208.0/24: 1
# 2001:4d78:2400::/40: 1
# 194.182.168.0/22: 1
# 2001:4d78:fe08::/48: 1
# 2001:4d78:800::/40: 1
# 2001:4d78:2000::/40: 1
# 2001:4d78:fe20::/48: 1
# 39.109.76.0/24: 1
# 2001:4d78:fe13::/48: 1
# 2001:4d78:1300::/40: 1
# 39.109.91.0/24: 1
# 2001:4d78:fe05::/48: 1
# 2001:4d78:500::/40: 1
# 103.144.40.0/24: 1
# 103.119.132.0/23: 1
# 39.109.69.0/24: 1
# 2001:1a08::/32: 1
# 2001:4d78:fe01::/48: 1
# 2001:4d78:100::/40: 1
# 103.109.5.0/24: 1
# 103.109.4.0/24: 1
# 2602:feda:d60::/48: 2
# 2001:4d78:1200::/40: 1
# 39.109.70.0/24: 1
# 39.109.68.0/24: 1
# 2001:4d78:fe17::/48: 1
# 2001:4d78:fe04::/48: 1
# 2001:4d78:400::/40: 1
# 38.60.131.0/24: 1
# 38.60.130.0/24: 1
# 38.60.203.0/24: 1
# 38.60.132.0/24: 1
# 38.60.129.0/24: 1
# 38.60.128.0/24: 1
# 2001:4d78:fe02::/48: 1
# 2001:4d78:200::/40: 1
# 45.200.122.0/23: 1
# 45.200.124.0/22: 1
# 156.240.57.0/24: 1
# 156.240.63.0/24: 1
# 156.240.72.0/22: 1
# 209.146.100.0/23: 1
# 209.146.102.0/23: 1
# 209.146.100.0/22: 1
# 2001:1540::/32: 1
# 39.109.67.0/24: 1
# 2001:4d78:fe03::/48: 1
# 2001:4d78:300::/40: 1
# 39.109.125.0/24: 1
# 2001:4d78:900::/40: 1
# 2001:4d78:fe09::/48: 1
# 103.95.131.0/24: 1
# 103.78.68.0/24: 1
# 103.100.53.0/24: 1
# 103.95.129.0/24: 1
# 156.226.6.0/24: 1
# 103.100.54.0/24: 1
# 103.78.70.0/24: 1
# 103.100.52.0/24: 1
# 103.95.130.0/24: 1
# 103.95.128.0/24: 1
# 103.78.69.0/24: 1
# 103.100.55.0/24: 1
# 103.78.71.0/24: 1
# 2001:4d78:700::/40: 1
# 2001:4d78:fe07::/48: 1
# 2001:4d78:fe19::/48: 1
# 2001:4d78:1900::/40: 1
# 2001:4d78:600::/40: 1
# 2001:4d78:2700::/40: 1
# 2001:4d78:fe06::/48: 1
# 2001:4d78:fe23::/48: 1
# 2001:4d78:fe21::/48: 1
# 2001:4d78:2300::/40: 1
# 162.250.4.0/24: 1
# 162.250.2.0/24: 1
# 2604:1380:80::/44: 1
# 74.80.100.0/24: 1
# 74.63.28.0/24: 1
# 2604:1380:c0::/44: 1
# 193.177.128.0/22: 1
# 193.177.129.0/24: 1
# 2001:4d78:fe22::/48: 1
# 2001:4d78:2200::/40: 1
# 91.198.30.0/24: 1
# 2a06:9300::/29: 1
# 2a05:7180::/29: 1
# 2a06:8500::/29: 1
# 2a0a:9040::/29: 1
# 2a05:bc0::/32: 1
# 2a07:a100::/29: 1
# 2a0c:e840::/29: 1
# 2a0c:dec0:f100::/48: 1
# 2a05:a1c0::/32: 1
# 2a0b:f240::/29: 1
# 2a06:1a80::/29: 1
# 2a10:300::/29: 1
# 2a00:1058::/32: 1
# 2a0a:2b00:10::/44: 1
# 2a07:a540::/29: 1
# 2a09:c580::/32: 1
# 2a05:96c0::/29: 1
# 2a02:2978::/32: 1
# 2a03:6980::/32: 1
# 2a02:20a8::/32: 1
# 2a0b:d240::/32: 1
# 2a00:16a0::/32: 1
# 2a02:2068:9000::/36: 1
# 2a02:2068::/29: 1
# 2a03:85c0:140::/48: 1
# 2a03:74c0::/32: 1
# 2800:280:4001::/48: 1
# 2803:7380:c000::/34: 1
# 2803:7380:8000::/34: 1
# 2404:6900::/33: 1
# 2605:380:53::/48: 1
# 2a00:11c0:2c::/48: 1
# 2403:e840::/33: 1
# 2a10:cc45:7ca::/48: 1
# 2a10:cc45:6c5::/48: 1
# 2a10:cc45:5e0::/48: 1
# 2a10:cc45:5ae::/48: 1
# 185.183.104.0/24: 1
# 45.12.222.0/24: 1
# 45.12.206.0/24: 1
# 91.90.122.0/24: 1
# 82.102.24.0/24: 1
# 84.39.112.0/24: 1
# 146.70.126.0/24: 1
# 146.70.135.0/24: 1
# 146.70.71.0/24: 1
# 146.70.99.0/24: 1
# 146.70.134.0/24: 1
# 146.70.26.0/24: 1
# 152.89.162.0/24: 1
# 37.120.137.0/24: 1
# 185.9.18.0/24: 1
# 37.120.213.0/24: 1
# 185.126.116.0/24: 1
# 185.126.151.0/24: 1
# 185.212.170.0/24: 1
# 185.230.125.0/24: 1
# 185.236.201.0/24: 1
# 91.193.4.0/24: 1
# 185.156.175.0/24: 1
# 193.38.137.0/24: 1
# 194.124.33.0/24: 1
# 195.206.105.0/24: 1
# 195.242.213.0/24: 1
# 217.138.203.0/24: 1
# 91.132.136.0/24: 1
# 45.134.17.0/24: 1
# 192.54.56.0/24: 1
# 185.23.56.0/22: 1
# 45.148.11.0/24: 1
# 216.131.121.0/24: 1
# 185.59.61.0/24: 1
# 185.59.63.0/24: 1
# 185.59.60.0/24: 1
# 172.84.180.0/24: 1
# 213.184.92.0/22: 1
# 172.84.181.0/24: 1
# 185.180.134.0/24: 1
# 91.236.216.0/22: 1
# 37.120.196.0/24: 1
# 37.120.146.0/24: 1
# 31.13.190.0/24: 1
# 37.120.223.0/24: 1
# 37.120.217.0/24: 1
# 37.120.195.0/24: 1
# 37.120.197.0/24: 1
# 37.120.222.0/24: 1
# 37.120.129.0/24: 1
# 83.97.23.0/24: 1
# 86.106.132.0/24: 1
# 91.207.172.0/24: 1
# 94.198.40.0/24: 1
# 93.177.73.0/24: 1
# 194.36.108.0/24: 1
# 152.89.163.0/24: 1
# 185.105.188.0/24: 1
# 185.120.16.0/24: 1
# 185.126.117.0/24: 1
# 185.130.184.0/24: 1
# 192.145.125.0/24: 1
# 193.176.87.0/24: 1
# 195.206.106.0/24: 1
# 212.103.50.0/24: 1
# 217.138.194.0/24: 1
# 217.138.216.0/24: 1
# 185.220.70.0/24: 1
# 185.232.23.0/24: 1
# 139.28.177.0/24: 1
# 193.27.14.0/24: 1
# 146.70.33.0/24: 1
# 45.87.212.0/24: 1
# 141.98.102.0/24: 1
# 146.70.36.0/24: 1
# 146.70.20.0/24: 1
# 146.70.62.0/24: 1
# 146.70.82.0/24: 1
# 146.70.101.0/24: 1
# 146.70.107.0/24: 1
# 146.70.117.0/24: 1
# 146.70.118.0/24: 1
# 146.70.139.0/24: 1
# 41.77.2.0/24: 13
# 86.107.100.0/24: 5
# 86.107.101.0/24: 5
# 2001:df7:e580::/48: 1
# 2401:d9c0:2000::/36: 1
# 2401:d9c0:2000::/44: 1
# 2001:dc7:fffb::/48: 40
# 2001:dc7:ffff::/48: 15
# 2001:dc7:3::/48: 40
# 2001:dc7::/48: 13
# 2001:dc7:1000::/48: 13
# 2001:dc7:fffe::/48: 15
# 2001:fd8:310:2::/64: 2
# 2001:fd8:310:9::/64: 2
# 2001:fd8:310:7::/64: 2
# 2001:fd8:2232::/64: 2
# 2001:4430:f:108::/64: 2
# 2001:4430:f:104::/64: 2
# 2001:4430:f:10a::/64: 2
# 2001:4430:f:116::/64: 2
# 2001:4430:f:106::/64: 2
# 2001:4430:f:114::/64: 2
# 2001:4430:f:118::/64: 2
# 2001:4430:f:109::/64: 2
# 2001:4430:f:107::/64: 2
# 2001:4430:f:117::/64: 2
# 2001:4430:f:112::/64: 2
# 2001:270:ff00:1::/64: 2
# 2001:4430:4:801::/64: 2
# 2001:270:ff00:2::/64: 2
# 2001:270:ff00::/64: 2
# 2001:ed0:a:401::/64: 2
# 2402:1:0:5::/64: 2
# 2402:1:0:4::/64: 2
# 2402:1:0:3::/64: 2
# 2001:270:ea34:f02c::/64: 2
# 2001:270:ea34:f002::/64: 2
# 2001:270:eb34:f03e::/64: 2
# 2001:270:ea34:f047::/64: 2
# 2001:270:eb34:f001::/64: 2
# 2001:270:ea34:f02f::/64: 2
# 2001:270:ea34:f001::/64: 2
# 2001:270:eb34:f02f::/64: 2
# 2001:270:ea34:f03e::/64: 2
# 2001:270:eb34:f02c::/64: 2
# 2001:4430:f:103::/64: 2
# 2001:4430:f:102::/64: 2
# 2001:4430:f:113::/64: 2
# 2001:4430:f:101::/64: 2
# 2001:4430:f:115::/64: 2
# 2001:4430:f:105::/64: 2
# 2001:4430:4:411::/64: 2
# 2001:ed0:f:899::/64: 2
# 2001:fd8:310:8::/64: 2
# 45.184.75.0/24: 3
# 49.237.10.0/24: 1
# 126.254.0.0/16: 1
# 168.181.158.0/23: 1
# 111.95.64.0/19: 1
# 118.96.36.0/22: 1
# 181.216.216.0/21: 1
# 181.218.144.0/21: 1
# 101.108.12.0/22: 1
# 201.108.160.0/20: 1
# 171.99.167.0/24: 1
# 173.228.157.0/24: 1
# 110.78.153.0/24: 1
# 38.106.128.0/21: 1
# 103.135.133.0/24: 1
# 186.119.64.0/20: 1
# 69.25.168.0/21: 1
# 189.218.8.0/24: 1
# 168.235.80.0/22: 1
# 99.244.32.0/19: 1
# 180.244.237.0/24: 1
# 82.40.0.0/15: 1
# 151.139.52.0/22: 1
# 104.144.36.0/22: 1
# 219.117.33.0/24: 1
# 118.70.160.0/20: 1
# 23.160.240.0/24: 1
# 1.1.249.0/24: 1
# 69.159.0.0/16: 1
# 3.208.0.0/12: 1
# 201.143.24.0/22: 1
# 130.105.72.0/22: 1
# 125.27.108.0/22: 1
# 74.105.0.0/16: 1
# 71.186.128.0/17: 1
# 173.63.0.0/16: 1
# 108.34.128.0/17: 1
# 100.16.0.0/16: 1
# 103.25.249.0/24: 1
# 103.253.43.0/24: 1
# 5.3.216.0/22: 1
# 107.77.236.0/24: 1
# 152.32.233.0/24: 1
# 103.156.155.0/24: 1
# 198.46.200.0/23: 1
# 103.180.250.0/24: 1
# 162.250.5.0/24: 1
# 180.248.0.0/20: 1
# 103.175.186.0/24: 1
# 194.117.226.0/23: 1
# 2a01:7820::/32: 1
# 2a00:8140:f000::/36: 1
# 2a01:4060::/32: 1
# 2a07:f00::/29: 1
# 2a02:2dc0::/32: 1
# 2a00:8140::/36: 1
# 2a00:8140:1000::/36: 1
# 2a03:9b40::/32: 1
# 2a00:18e0:6::/48: 1
# 2a00:18e0::/48: 1
# 2a02:7940::/32: 1
# 2a10:65c0::/29: 1
# 2a00:1828::/32: 1
# 2a02:5a0::/29: 1
# 2a02:2c60::/32: 1
# 205.65.136.0/22: 3
# 205.65.116.0/24: 3
# 205.65.119.0/24: 3
# 2a06:a005:554::/46: 2
# 2a05:4140:313::/48: 7
# 2a05:4140:305::/48: 7
# 2a05:4140:311::/48: 7
# 170.231.243.26/32: 1
# 2604:1740::/32: 4
# 177.70.2.0/24: 1
# 209.22.67.0/24: 1
# 209.22.66.0/24: 1
# 38.21.208.0/20: 1
# 101.109.16.0/20: 1
# 175.138.192.0/18: 1
# 125.24.253.0/24: 1
# 36.69.8.0/24: 1
# 72.13.46.0/24: 1
# 203.222.134.0/23: 1
# 115.64.226.0/23: 1
# 179.214.0.0/18: 1
# 64.42.182.0/24: 1
# 181.214.70.0/24: 1
# 36.74.40.0/21: 1
# 184.97.128.0/18: 1
# 116.90.169.0/24: 1
# 23.58.140.0/22: 1
# 117.1.28.0/23: 1
# 45.240.88.0/22: 1
# 117.4.240.0/20: 1
# 216.208.243.0/24: 1
# 153.192.0.0/11: 1
# 172.255.80.0/22: 1
# 203.128.95.0/24: 1
# 36.138.68.0/23: 1
# 72.211.64.0/18: 1
# 24.70.28.0/22: 1
# 36.72.80.0/21: 1
# 103.167.34.0/24: 1
# 139.84.224.0/19: 1
# 170.84.93.0/24: 1
# 192.210.173.0/24: 1
# 120.28.47.0/24: 1
# 177.190.215.0/24: 1
# 2a03:6504::/32: 1
# 2a03:6507::/32: 1
# 2a03:7203::/32: 1
# 2a03:7204::/32: 1
# 138.185.242.165/32: 1
# 27.0.196.0/24: 4
# 27.0.197.0/24: 4
# 103.229.161.0/24: 4

# %% [markdown]
# # Detecting Route Flaps

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def detect_route_flaps(from_time, until_time, flap_threshold=3, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    prefix_events = defaultdict(list)

    for rec in stream.records():
        for elem in rec:
            elem_time = datetime.utcfromtimestamp(elem.time)
            timestamp = elem.time
            prefix = elem.fields.get("prefix")

            if prefix is None:
                continue

            prefix_events[prefix].append((timestamp, elem.type))

    # Analyze flaps
    for prefix, events in prefix_events.items():
        events.sort()
        flap_count = 0
        last_event_type = None

        for timestamp, event_type in events:
            if last_event_type and last_event_type != event_type:
                flap_count += 1
            last_event_type = event_type

        if flap_count >= flap_threshold:
            print(f"Prefix {prefix} flapped {flap_count} times.")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
detect_route_flaps(from_time, until_time)
# Out:
# Prefix 130.137.111.0/24 flapped 60 times.
# Prefix 2a0e:9b43::/48 flapped 1172 times.
# Prefix 102.69.52.0/22 flapped 6 times.
# Prefix 2804:7160::/32 flapped 154 times.
# Prefix 55.58.238.0/24 flapped 175 times.
# Prefix 55.5.236.0/24 flapped 177 times.
# Prefix 67.211.53.0/24 flapped 522 times.
# Prefix 2a12:3fc2:8004::/46 flapped 34 times.
# Prefix 2a0e:b107:1d8::/46 flapped 680 times.
# Prefix 2a06:a005:554::/46 flapped 28 times.
# Prefix 2a10:cc45:625::/48 flapped 11 times.
# Prefix 2a10:cc45:7e0::/48 flapped 11 times.
# Prefix 2a10:cc45:438::/48 flapped 11 times.
# Prefix 2602:feda:bf0::/46 flapped 732 times.
# Prefix 2a05:da00::/29 flapped 57 times.
# Prefix 130.137.86.0/24 flapped 51 times.
# Prefix 202.45.88.0/24 flapped 10 times.
# Prefix 203.145.74.0/24 flapped 10 times.
# Prefix 203.145.78.0/24 flapped 10 times.
# Prefix 2606:2800:e004::/48 flapped 254 times.
# Prefix 2a10:cc45:68f::/48 flapped 9 times.
# Prefix 2a10:cc45:5e2::/48 flapped 11 times.
# Prefix 2a10:cc45:5ca::/48 flapped 11 times.
# Prefix 2a02:16c8:6000::/35 flapped 55 times.
# Prefix 2405:4000:800:8::/64 flapped 251 times.
# Prefix 130.137.81.0/24 flapped 47 times.
# Prefix 41.78.216.0/24 flapped 8 times.
# Prefix 102.217.52.0/23 flapped 8 times.
# Prefix 55.46.180.0/24 flapped 7 times.
# Prefix 55.46.178.0/24 flapped 7 times.
# Prefix 102.214.120.0/22 flapped 1638 times.
# Prefix 117.104.220.0/24 flapped 150 times.
# Prefix 117.104.217.0/24 flapped 150 times.
# Prefix 58.147.190.0/24 flapped 148 times.
# Prefix 117.104.203.0/24 flapped 150 times.
# Prefix 117.104.218.0/24 flapped 150 times.
# Prefix 117.104.194.0/24 flapped 150 times.
# Prefix 117.104.195.0/24 flapped 150 times.
# Prefix 117.104.214.0/24 flapped 150 times.
# Prefix 117.104.206.0/24 flapped 150 times.
# Prefix 117.104.215.0/24 flapped 150 times.
# Prefix 117.104.193.0/24 flapped 150 times.
# Prefix 117.104.201.0/24 flapped 150 times.
# Prefix 117.104.192.0/24 flapped 150 times.
# Prefix 117.104.200.0/24 flapped 150 times.
# Prefix 117.104.212.0/24 flapped 150 times.
# Prefix 117.104.198.0/24 flapped 150 times.
# Prefix 117.104.204.0/24 flapped 150 times.
# Prefix 117.104.222.0/24 flapped 150 times.
# Prefix 117.104.205.0/24 flapped 150 times.
# Prefix 117.104.210.0/24 flapped 150 times.
# Prefix 117.104.216.0/24 flapped 150 times.
# Prefix 117.104.221.0/24 flapped 150 times.
# Prefix 117.104.208.0/24 flapped 150 times.
# Prefix 117.104.211.0/24 flapped 150 times.
# Prefix 117.104.219.0/24 flapped 150 times.
# Prefix 58.147.189.0/24 flapped 148 times.
# Prefix 117.104.207.0/24 flapped 150 times.
# Prefix 117.104.209.0/24 flapped 150 times.
# Prefix 117.104.202.0/24 flapped 150 times.
# Prefix 117.104.196.0/24 flapped 150 times.
# Prefix 117.104.223.0/24 flapped 150 times.
# Prefix 117.104.197.0/24 flapped 150 times.
# Prefix 64.68.236.0/22 flapped 52 times.
# Prefix 168.196.156.0/24 flapped 86 times.
# Prefix 2606:7540:5::/48 flapped 8 times.
# Prefix 62.193.131.0/24 flapped 117 times.
# Prefix 181.225.43.0/24 flapped 110 times.
# Prefix 2804:4d48:4000::/42 flapped 583 times.
# Prefix 103.170.24.0/24 flapped 70 times.
# Prefix 103.170.25.0/24 flapped 70 times.
# Prefix 2a13:4c00:224f::/48 flapped 17 times.
# Prefix 130.137.136.0/24 flapped 46 times.
# Prefix 196.10.231.0/24 flapped 137 times.
# Prefix 2c0f:6e80::/28 flapped 10 times.
# Prefix 2c0f:6e80::/48 flapped 10 times.
# Prefix 240e:978:4984::/48 flapped 17 times.
# Prefix 2404:b300:33:1::/64 flapped 69 times.
# Prefix 2001:19f0:6000::/38 flapped 4 times.
# Prefix 2803:3420::/32 flapped 78 times.
# Prefix 61.246.46.0/24 flapped 53 times.
# Prefix 125.18.237.0/24 flapped 53 times.
# Prefix 61.246.45.0/24 flapped 53 times.
# Prefix 2a12:3fc2:800c::/46 flapped 46 times.
# Prefix 177.220.251.0/24 flapped 10 times.
# Prefix 103.155.5.0/24 flapped 4 times.
# Prefix 2a12:9cc0::/29 flapped 82 times.
# Prefix 2804:2000:1fff::/48 flapped 40 times.
# Prefix 23.39.47.0/24 flapped 16 times.
# Prefix 23.195.252.0/24 flapped 16 times.
# Prefix 23.40.60.0/24 flapped 16 times.
# Prefix 23.199.59.0/24 flapped 16 times.
# Prefix 23.194.190.0/24 flapped 16 times.
# Prefix 2804:361c::/32 flapped 4 times.
# Prefix 2400:cb00:144::/48 flapped 80 times.
# Prefix 138.118.237.0/24 flapped 26 times.
# Prefix 189.89.17.0/24 flapped 45 times.
# Prefix 189.89.22.0/24 flapped 17 times.
# Prefix 186.193.28.0/24 flapped 17 times.
# Prefix 138.118.239.0/24 flapped 21 times.
# Prefix 191.37.24.0/24 flapped 17 times.
# Prefix 2001:df1:7840::/48 flapped 84 times.
# Prefix 191.243.136.0/22 flapped 10 times.
# Prefix 2a10:cc45:444::/48 flapped 19 times.
# Prefix 2a10:cc45:79e::/48 flapped 19 times.
# Prefix 2a12:e341::/32 flapped 76 times.
# Prefix 147.112.0.0/16 flapped 110 times.
# Prefix 2602:80c:f000::/44 flapped 6 times.
# Prefix 103.165.248.0/24 flapped 117 times.
# Prefix 2401:ea00:25::/48 flapped 6 times.
# Prefix 2804:7f70::/32 flapped 4 times.
# Prefix 2602:fc24:13::/48 flapped 86 times.
# Prefix 186.250.248.0/23 flapped 17 times.
# Prefix 44.31.41.0/24 flapped 17 times.
# Prefix 2804:20fc:1b00::/48 flapped 422 times.
# Prefix 2a0a:6040:a450::/47 flapped 8 times.
# Prefix 2406:840:996f::/48 flapped 6 times.
# Prefix 2406:840:9967::/48 flapped 6 times.
# Prefix 2406:840:9966::/48 flapped 6 times.
# Prefix 68.68.97.0/24 flapped 37 times.
# Prefix 2001:dc6::/32 flapped 188 times.
# Prefix 2a0f:6580:e::/48 flapped 118 times.
# Prefix 2a0a:2f40::/32 flapped 80 times.
# Prefix 102.219.223.0/24 flapped 10 times.
# Prefix 2a0e:b107:1a38::/48 flapped 6 times.
# Prefix 2804:8768::/32 flapped 6 times.
# Prefix 2a10:cc45:7ce::/48 flapped 5 times.
# Prefix 2a10:cc45:75a::/48 flapped 7 times.
# Prefix 2a10:cc45:6c9::/48 flapped 5 times.
# Prefix 2a10:cc45:69b::/48 flapped 7 times.
# Prefix 2a10:cc45:56e::/48 flapped 5 times.
# Prefix 2804:64e4::/32 flapped 4 times.
# Prefix 2a0c:da04:18::/48 flapped 110 times.
# Prefix 2402:cec0::/32 flapped 90 times.
# Prefix 2001:1380:2000::/36 flapped 350 times.
# Prefix 2a06:8e40::/29 flapped 10 times.
# Prefix 195.177.202.0/23 flapped 101 times.
# Prefix 176.124.58.0/24 flapped 64 times.
# Prefix 112.137.160.0/24 flapped 10 times.
# Prefix 2804:4e44::/32 flapped 4 times.
# Prefix 177.190.215.0/24 flapped 26 times.
# Prefix 2804:12cc:8000::/33 flapped 291 times.
# Prefix 2804:12cc::/33 flapped 293 times.
# Prefix 2606:6200:1401::/48 flapped 45 times.
# Prefix 197.159.79.0/24 flapped 66 times.
# Prefix 197.159.72.0/24 flapped 16 times.
# Prefix 197.159.67.0/24 flapped 12 times.
# Prefix 41.222.209.0/24 flapped 16 times.
# Prefix 128.201.183.0/24 flapped 80 times.
# Prefix 2804:5ae0::/32 flapped 4 times.
# Prefix 138.122.48.0/22 flapped 28 times.
# Prefix 2404:8840::/32 flapped 8 times.
# Prefix 2804:8140:1000::/36 flapped 4 times.
# Prefix 2804:8140::/32 flapped 4 times.
# Prefix 2804:8140::/36 flapped 4 times.
# Prefix 2406:840:ff14::/48 flapped 6 times.
# Prefix 208.184.90.0/23 flapped 8 times.
# Prefix 12.0.126.0/23 flapped 8 times.
# Prefix 2804:5af8::/32 flapped 4 times.
# Prefix 197.159.69.0/24 flapped 14 times.
# Prefix 41.222.208.0/22 flapped 12 times.
# Prefix 41.78.81.0/24 flapped 12 times.
# Prefix 41.222.211.0/24 flapped 12 times.
# Prefix 2a0e:aa07:e035::/48 flapped 4 times.
# Prefix 2a0e:b107:178c::/48 flapped 4 times.
# Prefix 199.102.166.0/24 flapped 69 times.
# Prefix 2804:5530:4000::/34 flapped 4 times.
# Prefix 104.104.96.0/19 flapped 40 times.
# Prefix 104.102.96.0/19 flapped 40 times.
# Prefix 104.80.196.0/22 flapped 20 times.
# Prefix 104.73.8.0/22 flapped 20 times.
# Prefix 23.197.180.0/22 flapped 16 times.
# Prefix 23.197.176.0/22 flapped 16 times.
# Prefix 23.192.110.0/23 flapped 16 times.
# Prefix 23.35.66.0/23 flapped 16 times.
# Prefix 2605:52c0:4000::/48 flapped 8 times.
# Prefix 2620:12f:e000::/48 flapped 8 times.
# Prefix 2620:12f:e000::/40 flapped 8 times.
# Prefix 2a0e:b107:a50::/44 flapped 4 times.
# Prefix 2a0e:b107:a51::/48 flapped 4 times.
# Prefix 2a0e:b107:a56::/48 flapped 6 times.
# Prefix 2a0e:b107:a57::/48 flapped 6 times.
# Prefix 2a0e:b107:a52::/48 flapped 6 times.
# Prefix 2a0e:b107:a50::/48 flapped 6 times.
# Prefix 2a0e:b107:a55::/48 flapped 6 times.
# Prefix 2a0e:b107:a54::/48 flapped 6 times.
# Prefix 2a0e:b107:a53::/48 flapped 6 times.
# Prefix 2a0c:7a80::/29 flapped 146 times.
# Prefix 2602:fcef::/36 flapped 4 times.
# Prefix 2605:dd40:5275::/48 flapped 6 times.
# Prefix 2605:dd40:5ccc::/48 flapped 6 times.
# Prefix 2605:dd40:5bbb::/48 flapped 6 times.
# Prefix 2605:dd40:8202::/48 flapped 6 times.
# Prefix 2602:fe12:1::/48 flapped 6 times.
# Prefix 2602:fbaf:804::/48 flapped 6 times.
# Prefix 2602:fbaf:808::/47 flapped 6 times.
# Prefix 2602:fbaf:1::/48 flapped 6 times.
# Prefix 2602:fbaf:201::/48 flapped 6 times.
# Prefix 185.37.101.0/24 flapped 6 times.
# Prefix 2602:fb67::/48 flapped 6 times.
# Prefix 2602:feda:bd0::/48 flapped 4 times.
# Prefix 2804:2bb0:ff00::/40 flapped 4 times.
# Prefix 2a06:e881:2509::/48 flapped 4 times.
# Prefix 2605:d680::/32 flapped 6 times.
# Prefix 2804:4e4c:8000::/33 flapped 4 times.
# Prefix 2606:bdc0:5::/48 flapped 4 times.
# Prefix 2a0f:7d00:1::/48 flapped 4 times.
# Prefix 2602:fed2:770e::/48 flapped 4 times.
# Prefix 170.247.156.0/24 flapped 43 times.
# Prefix 168.194.135.0/24 flapped 51 times.
# Prefix 2a0b:4340:22::/48 flapped 8 times.
# Prefix 172.225.237.0/24 flapped 22 times.
# Prefix 172.225.236.0/24 flapped 22 times.
# Prefix 172.224.75.0/24 flapped 22 times.
# Prefix 172.225.235.0/24 flapped 22 times.
# Prefix 2a06:e881:6600::/48 flapped 4 times.
# Prefix 102.217.8.0/22 flapped 10 times.
# Prefix 2a07:aec0::/29 flapped 8 times.
# Prefix 2a0b:4340:9e::/48 flapped 4 times.
# Prefix 2a06:a004:5000::/36 flapped 6 times.
# Prefix 2405:84c0:9000::/44 flapped 18 times.
# Prefix 2405:84c0:ff3e::/48 flapped 20 times.
# Prefix 2405:84c0:ff60::/44 flapped 20 times.
# Prefix 2a0e:b107:1577::/48 flapped 4 times.
# Prefix 2a0e:aa07:e300::/48 flapped 4 times.
# Prefix 2a0e:b107:1806::/48 flapped 4 times.
# Prefix 2a12:dd47:8260::/48 flapped 4 times.
# Prefix 113.23.173.0/24 flapped 16 times.
# Prefix 45.183.178.0/24 flapped 44 times.
# Prefix 45.184.75.0/24 flapped 50 times.
# Prefix 168.176.213.0/24 flapped 8 times.
# Prefix 168.176.205.0/24 flapped 8 times.
# Prefix 2a0c:da04:14::/48 flapped 44 times.
# Prefix 2a05:b0c6:200b::/48 flapped 60 times.
# Prefix 240e:978:4980::/48 flapped 17 times.
# Prefix 2a0d:2587:8900::/48 flapped 111 times.
# Prefix 2600:1406:6000::/48 flapped 8 times.
# Prefix 2605:dd40:8d00::/44 flapped 17 times.
# Prefix 41.77.2.0/24 flapped 12 times.
# Prefix 2001:dc7:fffb::/48 flapped 22 times.
# Prefix 2001:dc7:ffff::/48 flapped 10 times.
# Prefix 2001:dc7:3::/48 flapped 22 times.
# Prefix 2001:dc7::/48 flapped 10 times.
# Prefix 2001:dc7:1000::/48 flapped 10 times.
# Prefix 2001:dc7:fffe::/48 flapped 10 times.
# Prefix 2404:3d00:41a8::/48 flapped 314 times.
# Prefix 154.216.64.0/19 flapped 5 times.
# Prefix 5.57.7.0/24 flapped 24 times.
# Prefix 2a0c:3800:300::/48 flapped 8 times.
# Prefix 110.172.150.0/24 flapped 48 times.
# Prefix 110.172.168.0/24 flapped 24 times.
# Prefix 154.91.126.0/24 flapped 8 times.
# Prefix 2606:cb40::/32 flapped 167 times.
# Prefix 2607:fcd0:fa82::/127 flapped 263 times.
# Prefix 2607:fcd0::66/127 flapped 263 times.
# Prefix 2607:fcd0:fa82::2/127 flapped 265 times.
# Prefix 2607:fcd0::68/127 flapped 265 times.
# Prefix 185.96.215.0/24 flapped 92 times.
# Prefix 2607:fcd0:106:2f0a::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:6400::/56 flapped 270 times.
# Prefix 2607:fcd0:fa80:9400::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3c00::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:2400::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:c00::/56 flapped 270 times.
# Prefix 2607:fcd0:fa80:400::/56 flapped 270 times.
# Prefix 2607:fcd0:fa80:4c00::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:1c00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:8c00::/56 flapped 270 times.
# Prefix 2607:fcd0:fa80:1400::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:1::c/126 flapped 244 times.
# Prefix 2607:fcd0:100:8e02::/64 flapped 244 times.
# Prefix 2607:fcd0:106:2f05::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3a01::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2::6/127 flapped 244 times.
# Prefix 2607:fcd0:fa80:3::/64 flapped 246 times.
# Prefix 2607:fcd0:100:e204::/64 flapped 246 times.
# Prefix 2607:fcd0::140/127 flapped 246 times.
# Prefix 2607:fcd0:fa80:2b00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:8300::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:6b00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:b00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3300::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:2300::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:1300::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:3b00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:6603::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2603::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:901::/127 flapped 246 times.
# Prefix 2607:fcd0:fa80:2901::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:1::10/126 flapped 246 times.
# Prefix 2607:fcd0:100:a40c::/64 flapped 246 times.
# Prefix 2607:fcd0:106:2f09::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:1a00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3a00::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:7a00::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:9200::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:6a00::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:5a00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:4200::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:2a00::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:8a00::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:a00::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:1200::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3d03::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2::/126 flapped 244 times.
# Prefix 2607:fcd0:fa80:6607::/64 flapped 246 times.
# Prefix 2607:fcd0:100:bf00::/56 flapped 270 times.
# Prefix 2607:fcd0:100:e203::/64 flapped 244 times.
# Prefix 2607:fcd0::4e/127 flapped 246 times.
# Prefix 2607:fcd0:fa80:6602::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:2602::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:1::14/126 flapped 244 times.
# Prefix 2607:fcd0:fa80:8900::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:8100::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:9100::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:4100::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:900::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2900::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:1100::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3900::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:200::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:3502::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3d02::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:6::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3000::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:1000::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:6000::/56 flapped 274 times.
# Prefix 2607:fcd0:fa81::/127 flapped 246 times.
# Prefix 2607:fcd0:fa80:7000::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:1800::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:9000::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:800::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:5000::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:6606::/64 flapped 248 times.
# Prefix 2607:fcd0:100:e202::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2601::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:6601::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2e01::/64 flapped 248 times.
# Prefix 2602:ffc5:60::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:1904::/64 flapped 246 times.
# Prefix 2607:fcd0:106:2f0c::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:100::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:2117::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:2700::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:1700::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:7700::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:6700::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:3700::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:4f00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:700::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:f00::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:2f00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:5f00::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:3f00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3d01::/64 flapped 246 times.
# Prefix 2607:fcd0:100:a400::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:1::1c/126 flapped 244 times.
# Prefix 2607:fcd0:100:e206::/64 flapped 246 times.
# Prefix 2607:fcd0::142/127 flapped 246 times.
# Prefix 2607:fcd0:fa80:3b02::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:6605::/64 flapped 248 times.
# Prefix 2607:fcd0:100:e201::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:5600::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2600::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:6600::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:8600::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:8e00::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:3600::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:e00::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:3e00::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:4600::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:600::/64 flapped 248 times.
# Prefix 2607:fcd0:106:2f0b::/64 flapped 246 times.
# Prefix 2607:fcd0:106:2100::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:4d00::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:3d00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:8500::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:6500::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:500::/56 flapped 272 times.
# Prefix 2607:fcd0:fa80:d00::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2500::/56 flapped 274 times.
# Prefix 2607:fcd0:fa80:1500::/64 flapped 246 times.
# Prefix 2607:fcd0:100:e205::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:3b01::/64 flapped 246 times.
# Prefix 2607:fcd0:fa80:2604::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:6604::/64 flapped 246 times.
# Prefix 2607:fcd0:100:e200::/64 flapped 244 times.
# Prefix 2607:fcd0:fa80:3f01::/64 flapped 248 times.
# Prefix 2607:fcd0:fa80:3701::/64 flapped 246 times.
# Prefix 195.202.91.0/24 flapped 98 times.
# Prefix 195.202.90.0/24 flapped 100 times.
# Prefix 31.131.2.0/24 flapped 13 times.
# Prefix 2a02:26f7:e600::/48 flapped 36 times.
# Prefix 2a02:26f7:e5c0::/48 flapped 36 times.
# Prefix 2a02:26f7:e640::/48 flapped 36 times.
# Prefix 2a02:26f7:78::/48 flapped 36 times.
# Prefix 2a02:26f7:f6c4::/48 flapped 36 times.
# Prefix 2600:1401:c000::/48 flapped 28 times.
# Prefix 2a03:5840:260::/48 flapped 38 times.
# Prefix 193.35.148.0/24 flapped 38 times.
# Prefix 2a0c:7fc0::/40 flapped 50 times.
# Prefix 2a05:3181:ffff::/48 flapped 258 times.
# Prefix 2a05:3181::/32 flapped 282 times.
# Prefix 24.75.246.0/23 flapped 10 times.
# Prefix 2a00:f40:f000::/48 flapped 55 times.
# Prefix 189.89.80.0/22 flapped 31 times.
# Prefix 189.89.83.0/24 flapped 31 times.
# Prefix 177.152.109.0/24 flapped 31 times.
# Prefix 201.162.82.0/23 flapped 33 times.
# Prefix 177.184.106.0/23 flapped 31 times.
# Prefix 187.73.70.0/23 flapped 33 times.
# Prefix 201.162.80.0/23 flapped 33 times.
# Prefix 186.235.202.0/23 flapped 31 times.
# Prefix 201.162.120.0/23 flapped 29 times.
# Prefix 186.235.200.0/23 flapped 33 times.
# Prefix 201.162.112.0/23 flapped 33 times.
# Prefix 201.162.114.0/23 flapped 31 times.
# Prefix 177.184.104.0/23 flapped 33 times.
# Prefix 201.162.86.0/23 flapped 29 times.
# Prefix 103.174.222.0/24 flapped 18 times.
# Prefix 186.249.78.0/24 flapped 33 times.
# Prefix 186.249.77.0/24 flapped 33 times.
# Prefix 45.169.154.0/24 flapped 27 times.
# Prefix 45.169.153.0/24 flapped 27 times.
# Prefix 45.169.155.0/24 flapped 29 times.
# Prefix 45.169.152.0/24 flapped 29 times.
# Prefix 170.231.143.0/24 flapped 31 times.
# Prefix 170.231.140.0/24 flapped 25 times.
# Prefix 170.231.141.0/24 flapped 23 times.
# Prefix 168.197.206.0/23 flapped 33 times.
# Prefix 45.164.156.0/23 flapped 35 times.
# Prefix 45.164.158.0/24 flapped 33 times.
# Prefix 45.164.157.0/24 flapped 35 times.
# Prefix 45.164.159.0/24 flapped 33 times.
# Prefix 45.164.158.0/23 flapped 19 times.
# Prefix 177.46.52.0/22 flapped 31 times.
# Prefix 45.7.92.0/22 flapped 92 times.
# Prefix 209.236.92.0/22 flapped 24 times.
# Prefix 189.126.76.0/23 flapped 27 times.
# Prefix 189.126.78.0/23 flapped 21 times.
# Prefix 189.126.72.0/23 flapped 27 times.
# Prefix 189.126.74.0/23 flapped 25 times.
# Prefix 177.128.212.0/23 flapped 31 times.
# Prefix 200.229.220.0/23 flapped 29 times.
# Prefix 177.128.208.0/23 flapped 29 times.
# Prefix 177.128.214.0/23 flapped 31 times.
# Prefix 177.128.210.0/23 flapped 31 times.
# Prefix 177.152.108.0/24 flapped 27 times.
# Prefix 177.155.148.0/23 flapped 31 times.
# Prefix 177.155.150.0/23 flapped 31 times.
# Prefix 177.155.146.0/23 flapped 29 times.
# Prefix 177.37.176.0/20 flapped 35 times.
# Prefix 177.37.144.0/20 flapped 29 times.
# Prefix 177.37.208.0/20 flapped 33 times.
# Prefix 187.19.192.0/20 flapped 23 times.
# Prefix 187.19.224.0/20 flapped 21 times.
# Prefix 168.232.246.0/24 flapped 25 times.
# Prefix 168.232.245.0/24 flapped 27 times.
# Prefix 168.232.244.0/24 flapped 27 times.
# Prefix 168.232.247.0/24 flapped 33 times.
# Prefix 189.39.128.0/24 flapped 27 times.
# Prefix 167.250.150.0/24 flapped 27 times.
# Prefix 170.246.132.0/24 flapped 27 times.
# Prefix 189.39.129.0/24 flapped 27 times.
# Prefix 167.250.151.0/24 flapped 27 times.
# Prefix 189.39.130.0/24 flapped 29 times.
# Prefix 170.231.180.0/24 flapped 29 times.
# Prefix 167.250.148.0/24 flapped 25 times.
# Prefix 189.89.18.0/24 flapped 29 times.
# Prefix 167.250.149.0/24 flapped 29 times.
# Prefix 187.62.159.0/24 flapped 21 times.
# Prefix 187.62.154.0/23 flapped 3 times.
# Prefix 187.62.153.0/24 flapped 3 times.
# Prefix 187.62.154.0/24 flapped 3 times.
# Prefix 187.62.156.0/24 flapped 21 times.
# Prefix 187.62.156.0/23 flapped 3 times.
# Prefix 187.62.158.0/24 flapped 3 times.
# Prefix 187.62.158.0/23 flapped 3 times.
# Prefix 187.62.152.0/24 flapped 3 times.
# Prefix 2407:d340:7121::/48 flapped 10 times.
# Prefix 2407:d340:7129::/48 flapped 7 times.
# Prefix 2407:d340:712b::/48 flapped 8 times.
# Prefix 2407:d340:7123::/48 flapped 10 times.
# Prefix 177.154.194.0/23 flapped 25 times.
# Prefix 177.154.196.0/23 flapped 23 times.
# Prefix 177.154.192.0/23 flapped 23 times.
# Prefix 177.154.202.0/23 flapped 29 times.
# Prefix 177.154.204.0/23 flapped 31 times.
# Prefix 177.154.198.0/23 flapped 31 times.
# Prefix 177.154.200.0/23 flapped 31 times.
# Prefix 189.89.84.0/22 flapped 25 times.
# Prefix 189.89.95.0/24 flapped 5 times.
# Prefix 45.236.118.0/23 flapped 33 times.
# Prefix 45.236.116.0/23 flapped 33 times.
# Prefix 45.164.52.0/23 flapped 35 times.
# Prefix 45.164.54.0/23 flapped 35 times.
# Prefix 138.97.116.0/23 flapped 33 times.
# Prefix 138.97.118.0/23 flapped 35 times.
# Prefix 2a00:18c0:3000::/36 flapped 204 times.
# Prefix 185.154.152.0/22 flapped 19 times.
# Prefix 2001:67c:20fc::/48 flapped 12 times.
# Prefix 2001:270:eb34:f02c::/64 flapped 9 times.
# Prefix 2001:270:ea34:f03e::/64 flapped 9 times.
# Prefix 2001:270:eb34:f02f::/64 flapped 9 times.
# Prefix 2001:270:ea34:f001::/64 flapped 9 times.
# Prefix 2001:270:ea34:f02f::/64 flapped 9 times.
# Prefix 2001:270:eb34:f001::/64 flapped 9 times.
# Prefix 2001:270:ea34:f047::/64 flapped 9 times.
# Prefix 2001:270:eb34:f03e::/64 flapped 9 times.
# Prefix 2001:270:ea34:f002::/64 flapped 9 times.
# Prefix 2001:270:ea34:f02c::/64 flapped 9 times.
# Prefix 2001:ed0:a:401::/64 flapped 9 times.
# Prefix 2001:270:ff00::/64 flapped 9 times.
# Prefix 2001:270:ff00:2::/64 flapped 9 times.
# Prefix 2001:4430:4:801::/64 flapped 9 times.
# Prefix 2001:270:ff00:1::/64 flapped 9 times.
# Prefix 2001:4430:4:411::/64 flapped 9 times.
# Prefix 2001:4430:f:105::/64 flapped 9 times.
# Prefix 2001:4430:f:115::/64 flapped 9 times.
# Prefix 2001:4430:f:101::/64 flapped 9 times.
# Prefix 2001:4430:f:113::/64 flapped 9 times.
# Prefix 2001:4430:f:102::/64 flapped 9 times.
# Prefix 2001:4430:f:103::/64 flapped 9 times.
# Prefix 2001:fd8:310:8::/64 flapped 9 times.
# Prefix 2001:ed0:f:899::/64 flapped 9 times.
# Prefix 2001:4430:f:112::/64 flapped 9 times.
# Prefix 2001:4430:f:117::/64 flapped 9 times.
# Prefix 2001:4430:f:107::/64 flapped 9 times.
# Prefix 2001:4430:f:109::/64 flapped 9 times.
# Prefix 2001:4430:f:118::/64 flapped 9 times.
# Prefix 2001:4430:f:114::/64 flapped 9 times.
# Prefix 2001:4430:f:106::/64 flapped 9 times.
# Prefix 2001:4430:f:116::/64 flapped 9 times.
# Prefix 2001:4430:f:10a::/64 flapped 9 times.
# Prefix 2001:4430:f:104::/64 flapped 9 times.
# Prefix 2001:4430:f:108::/64 flapped 9 times.
# Prefix 2001:fd8:2232::/64 flapped 9 times.
# Prefix 2001:fd8:310:7::/64 flapped 9 times.
# Prefix 2001:fd8:310:9::/64 flapped 9 times.
# Prefix 2001:fd8:310:2::/64 flapped 9 times.
# Prefix 2001:fd8:62::/64 flapped 9 times.
# Prefix 2001:fd8:310:1::/64 flapped 9 times.
# Prefix 2402:1:0:3::/64 flapped 9 times.
# Prefix 2402:1:0:4::/64 flapped 9 times.
# Prefix 2402:1:0:5::/64 flapped 9 times.
# Prefix 185.18.201.0/24 flapped 64 times.
# Prefix 170.84.48.0/23 flapped 31 times.
# Prefix 170.84.49.0/24 flapped 13 times.
# Prefix 170.84.50.0/23 flapped 13 times.
# Prefix 170.84.48.0/24 flapped 29 times.
# Prefix 170.84.51.0/24 flapped 11 times.
# Prefix 170.84.50.0/24 flapped 13 times.
# Prefix 179.63.174.0/23 flapped 33 times.
# Prefix 179.63.172.0/23 flapped 23 times.
# Prefix 177.155.144.0/23 flapped 29 times.
# Prefix 143.137.226.0/23 flapped 27 times.
# Prefix 143.137.224.0/23 flapped 31 times.
# Prefix 186.195.4.0/23 flapped 27 times.
# Prefix 186.195.2.0/23 flapped 29 times.
# Prefix 186.195.0.0/22 flapped 29 times.
# Prefix 186.195.0.0/23 flapped 29 times.
# Prefix 186.195.0.0/21 flapped 29 times.
# Prefix 186.195.6.0/23 flapped 29 times.
# Prefix 186.195.4.0/22 flapped 27 times.
# Prefix 45.191.31.0/24 flapped 7 times.
# Prefix 45.191.30.0/24 flapped 9 times.
# Prefix 45.191.29.0/24 flapped 11 times.
# Prefix 45.191.28.0/24 flapped 31 times.
# Prefix 155.143.244.0/24 flapped 75 times.
# Prefix 199.19.54.0/24 flapped 17 times.
# Prefix 2804:14d:14a4::/48 flapped 14 times.
# Prefix 2804:14d:14a2::/48 flapped 14 times.
# Prefix 2804:14d:14a3::/48 flapped 14 times.
# Prefix 134.111.0.0/16 flapped 16 times.
# Prefix 2001:4479:9600:7400::/56 flapped 3 times.
# Prefix 88.221.81.0/24 flapped 5 times.
# Prefix 138.117.204.0/23 flapped 12 times.
# Prefix 177.221.74.0/23 flapped 6 times.
# Prefix 138.117.206.0/23 flapped 12 times.
# Prefix 177.221.76.0/23 flapped 4 times.
# Prefix 177.125.88.0/23 flapped 8 times.
# Prefix 177.125.86.0/23 flapped 6 times.
# Prefix 168.181.80.0/23 flapped 10 times.
# Prefix 177.125.94.0/23 flapped 8 times.
# Prefix 177.125.90.0/23 flapped 4 times.
# Prefix 177.125.80.0/23 flapped 6 times.
# Prefix 177.125.92.0/23 flapped 8 times.
# Prefix 177.221.72.0/23 flapped 10 times.
# Prefix 187.19.122.0/24 flapped 25 times.
# Prefix 187.19.123.0/24 flapped 25 times.
# Prefix 138.186.132.0/24 flapped 29 times.
# Prefix 187.19.127.0/24 flapped 25 times.
# Prefix 187.19.119.0/24 flapped 21 times.
# Prefix 187.19.114.0/24 flapped 19 times.
# Prefix 187.19.115.0/24 flapped 19 times.
# Prefix 187.19.121.0/24 flapped 19 times.
# Prefix 187.19.120.0/24 flapped 21 times.
# Prefix 187.19.117.0/24 flapped 17 times.
# Prefix 187.19.125.0/24 flapped 21 times.
# Prefix 187.19.124.0/24 flapped 21 times.
# Prefix 187.19.126.0/24 flapped 25 times.
# Prefix 187.19.113.0/24 flapped 15 times.
# Prefix 138.186.134.0/24 flapped 13 times.
# Prefix 138.186.133.0/24 flapped 13 times.
# Prefix 187.19.116.0/24 flapped 19 times.
# Prefix 187.19.118.0/24 flapped 21 times.
# Prefix 138.59.42.0/23 flapped 29 times.
# Prefix 138.59.40.0/23 flapped 27 times.
# Prefix 177.125.82.0/23 flapped 6 times.
# Prefix 177.221.78.0/23 flapped 8 times.
# Prefix 177.125.84.0/23 flapped 8 times.
# Prefix 168.181.82.0/23 flapped 8 times.
# Prefix 170.247.158.0/24 flapped 21 times.
# Prefix 201.158.62.0/24 flapped 29 times.
# Prefix 201.158.61.0/24 flapped 27 times.
# Prefix 168.194.134.0/24 flapped 27 times.
# Prefix 170.247.157.0/24 flapped 21 times.
# Prefix 170.247.159.0/24 flapped 21 times.
# Prefix 201.158.60.0/24 flapped 27 times.
# Prefix 201.158.63.0/24 flapped 29 times.
# Prefix 168.194.132.0/24 flapped 29 times.
# Prefix 168.194.133.0/24 flapped 29 times.
# Prefix 191.242.56.0/22 flapped 21 times.
# Prefix 191.242.60.0/22 flapped 29 times.
# Prefix 186.193.16.0/24 flapped 31 times.
# Prefix 186.193.25.0/24 flapped 21 times.
# Prefix 186.193.21.0/24 flapped 19 times.
# Prefix 186.193.17.0/24 flapped 15 times.
# Prefix 187.94.208.0/24 flapped 15 times.
# Prefix 170.80.255.0/24 flapped 25 times.
# Prefix 170.80.252.0/24 flapped 27 times.
# Prefix 170.80.253.0/24 flapped 25 times.
# Prefix 170.80.254.0/24 flapped 25 times.
# Prefix 187.94.219.0/24 flapped 21 times.
# Prefix 186.193.26.0/24 flapped 21 times.
# Prefix 187.94.216.0/24 flapped 21 times.
# Prefix 186.193.27.0/24 flapped 21 times.
# Prefix 187.94.217.0/24 flapped 21 times.
# Prefix 187.94.218.0/24 flapped 21 times.
# Prefix 187.94.212.0/24 flapped 19 times.
# Prefix 187.94.213.0/24 flapped 19 times.
# Prefix 186.193.24.0/24 flapped 19 times.
# Prefix 187.94.209.0/24 flapped 15 times.
# Prefix 186.193.20.0/24 flapped 15 times.
# Prefix 45.191.28.0/23 flapped 27 times.
# Prefix 45.191.30.0/23 flapped 19 times.
# Prefix 45.226.199.0/24 flapped 29 times.
# Prefix 177.223.4.0/22 flapped 15 times.
# Prefix 177.223.8.0/22 flapped 21 times.
# Prefix 177.23.136.0/22 flapped 29 times.
# Prefix 177.223.0.0/22 flapped 19 times.
# Prefix 177.223.12.0/22 flapped 19 times.
# Prefix 177.23.140.0/22 flapped 29 times.
# Prefix 177.23.140.0/24 flapped 31 times.
# Prefix 177.71.106.0/23 flapped 17 times.
# Prefix 177.71.104.0/23 flapped 27 times.
# Prefix 189.1.132.0/22 flapped 15 times.
# Prefix 177.136.148.0/22 flapped 15 times.
# Prefix 177.12.36.0/22 flapped 15 times.
# Prefix 177.12.4.0/22 flapped 17 times.
# Prefix 189.1.128.0/22 flapped 19 times.
# Prefix 177.136.128.0/22 flapped 19 times.
# Prefix 177.12.16.0/22 flapped 19 times.
# Prefix 177.12.52.0/22 flapped 21 times.
# Prefix 189.1.140.0/22 flapped 21 times.
# Prefix 177.136.156.0/22 flapped 21 times.
# Prefix 177.12.12.0/22 flapped 21 times.
# Prefix 177.12.48.0/22 flapped 21 times.
# Prefix 189.1.136.0/22 flapped 21 times.
# Prefix 177.12.24.0/22 flapped 21 times.
# Prefix 177.136.136.0/22 flapped 23 times.
# Prefix 177.12.60.0/22 flapped 31 times.
# Prefix 177.12.20.0/22 flapped 31 times.
# Prefix 177.136.132.0/22 flapped 31 times.
# Prefix 177.12.56.0/22 flapped 25 times.
# Prefix 177.136.144.0/22 flapped 27 times.
# Prefix 177.12.32.0/22 flapped 27 times.
# Prefix 177.12.0.0/22 flapped 25 times.
# Prefix 177.136.140.0/22 flapped 31 times.
# Prefix 177.12.28.0/22 flapped 31 times.
# Prefix 177.136.152.0/22 flapped 15 times.
# Prefix 177.12.40.0/22 flapped 15 times.
# Prefix 177.12.8.0/22 flapped 15 times.
# Prefix 177.12.44.0/22 flapped 15 times.
# Prefix 2001:678:ed0::/48 flapped 18 times.
# Prefix 199.192.180.0/22 flapped 28 times.
# Prefix 130.137.150.0/24 flapped 54 times.
# Prefix 205.91.64.0/20 flapped 15 times.
# Prefix 205.95.0.0/19 flapped 15 times.
# Prefix 205.93.96.0/19 flapped 16 times.
# Prefix 186.249.74.0/24 flapped 29 times.
# Prefix 186.249.75.0/24 flapped 29 times.
# Prefix 186.249.76.0/24 flapped 27 times.
# Prefix 186.249.69.0/24 flapped 23 times.
# Prefix 186.249.70.0/24 flapped 29 times.
# Prefix 186.249.71.0/24 flapped 27 times.
# Prefix 186.249.72.0/24 flapped 27 times.
# Prefix 186.249.67.0/24 flapped 27 times.
# Prefix 186.249.68.0/24 flapped 25 times.
# Prefix 186.249.73.0/24 flapped 29 times.
# Prefix 45.236.116.0/24 flapped 25 times.
# Prefix 45.236.117.0/24 flapped 25 times.
# Prefix 45.236.118.0/24 flapped 25 times.
# Prefix 45.236.119.0/24 flapped 21 times.
# Prefix 206.42.32.0/20 flapped 17 times.
# Prefix 206.42.16.0/20 flapped 17 times.
# Prefix 206.42.48.0/20 flapped 13 times.
# Prefix 206.42.0.0/20 flapped 11 times.
# Prefix 177.10.168.0/24 flapped 23 times.
# Prefix 177.10.169.0/24 flapped 23 times.
# Prefix 177.10.170.0/24 flapped 23 times.
# Prefix 179.63.174.0/24 flapped 25 times.
# Prefix 179.63.172.0/24 flapped 23 times.
# Prefix 179.63.173.0/24 flapped 23 times.
# Prefix 170.0.62.0/24 flapped 23 times.
# Prefix 186.235.198.0/23 flapped 23 times.
# Prefix 201.162.76.0/23 flapped 23 times.
# Prefix 201.162.110.0/23 flapped 23 times.
# Prefix 186.235.196.0/23 flapped 25 times.
# Prefix 187.73.66.0/23 flapped 25 times.
# Prefix 201.162.108.0/23 flapped 25 times.
# Prefix 177.184.100.0/23 flapped 25 times.
# Prefix 201.162.74.0/23 flapped 21 times.
# Prefix 177.184.124.0/23 flapped 21 times.
# Prefix 186.235.220.0/23 flapped 21 times.
# Prefix 201.162.64.0/23 flapped 19 times.
# Prefix 201.162.98.0/23 flapped 19 times.
# Prefix 186.235.218.0/23 flapped 19 times.
# Prefix 187.73.88.0/23 flapped 19 times.
# Prefix 177.184.122.0/23 flapped 19 times.
# Prefix 201.162.96.0/23 flapped 17 times.
# Prefix 186.235.216.0/23 flapped 17 times.
# Prefix 187.73.86.0/23 flapped 17 times.
# Prefix 187.73.94.0/23 flapped 17 times.
# Prefix 201.162.102.0/23 flapped 17 times.
# Prefix 187.73.92.0/23 flapped 17 times.
# Prefix 201.162.68.0/23 flapped 15 times.
# Prefix 177.184.126.0/23 flapped 15 times.
# Prefix 186.235.222.0/23 flapped 15 times.
# Prefix 201.162.100.0/23 flapped 15 times.
# Prefix 187.73.90.0/23 flapped 15 times.
# Prefix 201.162.66.0/23 flapped 15 times.
# Prefix 201.162.124.0/23 flapped 15 times.
# Prefix 201.162.90.0/23 flapped 15 times.
# Prefix 187.73.80.0/23 flapped 15 times.
# Prefix 177.184.114.0/23 flapped 15 times.
# Prefix 186.235.210.0/23 flapped 15 times.
# Prefix 201.162.122.0/23 flapped 15 times.
# Prefix 201.162.88.0/23 flapped 13 times.
# Prefix 187.73.78.0/23 flapped 13 times.
# Prefix 177.184.112.0/23 flapped 11 times.
# Prefix 186.235.208.0/23 flapped 11 times.
# Prefix 177.184.120.0/23 flapped 11 times.
# Prefix 201.162.94.0/23 flapped 11 times.
# Prefix 177.184.118.0/23 flapped 11 times.
# Prefix 186.235.214.0/23 flapped 11 times.
# Prefix 187.73.84.0/23 flapped 11 times.
# Prefix 201.162.126.0/23 flapped 11 times.
# Prefix 201.162.92.0/23 flapped 9 times.
# Prefix 187.73.82.0/23 flapped 9 times.
# Prefix 177.184.116.0/23 flapped 9 times.
# Prefix 186.235.212.0/23 flapped 9 times.
# Prefix 186.235.206.0/23 flapped 29 times.
# Prefix 187.73.76.0/23 flapped 29 times.
# Prefix 201.162.118.0/23 flapped 29 times.
# Prefix 201.162.84.0/23 flapped 29 times.
# Prefix 177.184.108.0/23 flapped 27 times.
# Prefix 186.235.204.0/23 flapped 25 times.
# Prefix 187.73.74.0/23 flapped 25 times.
# Prefix 201.162.116.0/23 flapped 25 times.
# Prefix 187.73.64.0/22 flapped 23 times.
# Prefix 186.235.194.0/23 flapped 23 times.
# Prefix 187.73.64.0/23 flapped 23 times.
# Prefix 201.162.106.0/23 flapped 25 times.
# Prefix 177.184.98.0/23 flapped 27 times.
# Prefix 177.184.96.0/23 flapped 27 times.
# Prefix 186.235.192.0/23 flapped 27 times.
# Prefix 201.162.104.0/23 flapped 27 times.
# Prefix 201.162.70.0/23 flapped 27 times.
# Prefix 201.162.78.0/23 flapped 25 times.
# Prefix 187.73.68.0/23 flapped 25 times.
# Prefix 177.184.102.0/23 flapped 23 times.
# Prefix 138.204.120.0/23 flapped 21 times.
# Prefix 181.191.218.0/23 flapped 25 times.
# Prefix 191.242.66.0/23 flapped 11 times.
# Prefix 191.242.64.0/23 flapped 11 times.
# Prefix 191.242.70.0/23 flapped 7 times.
# Prefix 191.242.68.0/23 flapped 7 times.
# Prefix 187.33.237.0/24 flapped 23 times.
# Prefix 177.75.78.0/24 flapped 23 times.
# Prefix 187.33.232.0/24 flapped 21 times.
# Prefix 177.75.73.0/24 flapped 21 times.
# Prefix 138.121.122.0/23 flapped 21 times.
# Prefix 138.121.120.0/23 flapped 19 times.
# Prefix 139.175.41.0/24 flapped 4 times.
# Prefix 104.123.220.0/24 flapped 18 times.
# Prefix 104.123.222.0/24 flapped 18 times.
# Prefix 104.123.223.0/24 flapped 18 times.
# Prefix 104.123.221.0/24 flapped 18 times.
# Prefix 2a11:f2c0:fff0::/48 flapped 4 times.
# Prefix 155.30.122.0/24 flapped 16 times.
# Prefix 189.201.236.0/23 flapped 5 times.
# Prefix 45.163.236.0/24 flapped 5 times.
# Prefix 45.163.237.0/24 flapped 9 times.
# Prefix 45.163.239.0/24 flapped 7 times.
# Prefix 45.163.238.0/24 flapped 7 times.
# Prefix 168.196.90.0/23 flapped 5 times.
# Prefix 138.97.14.0/23 flapped 5 times.
# Prefix 138.97.12.0/23 flapped 7 times.
# Prefix 168.196.88.0/23 flapped 5 times.
# Prefix 138.99.168.0/24 flapped 13 times.
# Prefix 138.99.169.0/24 flapped 15 times.
# Prefix 138.99.171.0/24 flapped 17 times.
# Prefix 138.99.170.0/24 flapped 15 times.
# Prefix 170.231.142.0/24 flapped 19 times.
# Prefix 45.164.156.0/24 flapped 13 times.
# Prefix 2605:4580:3142::/48 flapped 26 times.
# Prefix 2406:da1b:400::/38 flapped 62 times.
# Prefix 27.0.196.0/24 flapped 8 times.
# Prefix 27.0.197.0/24 flapped 8 times.
# Prefix 103.229.161.0/24 flapped 6 times.
# Prefix 2001:4479:1903:5a00::/56 flapped 7 times.
# Prefix 200.33.67.0/24 flapped 57 times.
# Prefix 205.93.32.0/19 flapped 15 times.
# Prefix 205.78.192.0/20 flapped 12 times.
# Prefix 205.106.80.0/22 flapped 14 times.
# Prefix 205.106.100.0/22 flapped 13 times.
# Prefix 205.93.64.0/19 flapped 13 times.
# Prefix 209.163.127.0/24 flapped 20 times.
# Prefix 41.75.208.0/20 flapped 86 times.
# Prefix 151.118.58.0/24 flapped 14 times.
# Prefix 2a0e:8f02:2134::/48 flapped 4 times.
# Prefix 2a0e:b107:12f1::/48 flapped 4 times.
# Prefix 204.79.142.0/24 flapped 20 times.
# Prefix 198.97.43.0/24 flapped 20 times.
# Prefix 198.97.42.0/24 flapped 20 times.
# Prefix 198.97.41.0/24 flapped 20 times.
# Prefix 192.52.249.0/24 flapped 20 times.
# Prefix 192.52.248.0/24 flapped 20 times.
# Prefix 192.52.247.0/24 flapped 16 times.
# Prefix 2804:2844::/34 flapped 4 times.
# Prefix 203.130.50.0/24 flapped 40 times.
# Prefix 220.243.248.0/24 flapped 36 times.
# Prefix 193.105.156.0/24 flapped 60 times.
# Prefix 2a10:4646:12::/48 flapped 10 times.
# Prefix 185.26.155.0/24 flapped 6 times.
# Prefix 41.78.218.0/24 flapped 10 times.
# Prefix 41.78.219.0/24 flapped 10 times.
# Prefix 2a0c:e643:abcd::/48 flapped 89 times.
# Prefix 2a05:dfc7:2100::/40 flapped 25 times.
# Prefix 194.6.243.0/24 flapped 12 times.
# Prefix 217.20.96.0/20 flapped 14 times.
# Prefix 2600:5800:1601::/48 flapped 96 times.
# Prefix 113.212.161.0/24 flapped 6 times.
# Prefix 113.212.162.0/24 flapped 4 times.
# Prefix 113.212.167.0/24 flapped 4 times.
# Prefix 45.175.74.0/23 flapped 4 times.
# Prefix 184.164.245.0/24 flapped 22 times.
# Prefix 2402:f800:df00::/48 flapped 157 times.
# Prefix 2402:f800::/48 flapped 157 times.
# Prefix 2402:f800:ffff::/48 flapped 157 times.
# Prefix 2402:f800:cf00::/48 flapped 157 times.
# Prefix 2402:f800:ef00::/48 flapped 157 times.
# Prefix 2402:f800:ff00::/48 flapped 157 times.
# Prefix 195.33.232.0/24 flapped 16 times.
# Prefix 45.139.208.0/24 flapped 26 times.
# Prefix 195.114.122.0/24 flapped 42 times.
# Prefix 185.74.212.0/22 flapped 12 times.
# Prefix 2605:4400:5::/48 flapped 6 times.
# Prefix 181.191.89.0/24 flapped 14 times.
# Prefix 155.30.120.0/24 flapped 14 times.
# Prefix 155.30.125.0/24 flapped 14 times.
# Prefix 2400:58a0:1800::/44 flapped 87 times.
# Prefix 41.86.37.0/24 flapped 50 times.
# Prefix 2804:20fc:200::/40 flapped 55 times.
# Prefix 181.225.48.0/24 flapped 101 times.
# Prefix 2a12:be40::/29 flapped 4 times.
# Prefix 2a12:be40:2::/48 flapped 4 times.
# Prefix 2a01:170:1050::/48 flapped 4 times.
# Prefix 2a12:be40:1::/48 flapped 4 times.
# Prefix 2a12:be40::/48 flapped 4 times.
# Prefix 2a04:1bc0::/32 flapped 4 times.
# Prefix 2a04:1bc3::/32 flapped 4 times.
# Prefix 2a04:1bc7::/32 flapped 4 times.
# Prefix 209.205.170.0/24 flapped 37 times.
# Prefix 8.42.238.0/23 flapped 37 times.
# Prefix 216.238.249.0/24 flapped 35 times.
# Prefix 216.238.248.0/24 flapped 35 times.
# Prefix 8.42.224.0/22 flapped 35 times.
# Prefix 8.42.228.0/23 flapped 33 times.
# Prefix 43.225.74.0/23 flapped 10 times.
# Prefix 103.168.180.0/23 flapped 10 times.
# Prefix 103.44.54.0/23 flapped 10 times.
# Prefix 103.49.234.0/24 flapped 10 times.
# Prefix 103.44.52.0/23 flapped 10 times.
# Prefix 103.49.234.0/23 flapped 10 times.
# Prefix 103.168.180.0/24 flapped 10 times.
# Prefix 43.225.72.0/23 flapped 10 times.
# Prefix 103.168.181.0/24 flapped 10 times.
# Prefix 178.175.180.0/23 flapped 6 times.
# Prefix 178.175.180.0/24 flapped 8 times.
# Prefix 178.175.181.0/24 flapped 6 times.
# Prefix 2400:cb00:424::/48 flapped 16 times.
# Prefix 2804:14d:1495::/48 flapped 16 times.
# Prefix 2804:14d:1498::/48 flapped 14 times.
# Prefix 2804:14d:1493::/48 flapped 16 times.
# Prefix 2a04:5b05::/32 flapped 4 times.
# Prefix 195.114.123.0/24 flapped 59 times.
# Prefix 199.47.232.0/22 flapped 59 times.
# Prefix 103.141.159.0/24 flapped 70 times.
# Prefix 103.141.158.0/24 flapped 70 times.
# Prefix 38.7.139.0/24 flapped 4 times.
# Prefix 187.62.238.0/23 flapped 4 times.
# Prefix 179.127.8.0/24 flapped 8 times.
# Prefix 179.48.227.0/24 flapped 30 times.
# Prefix 179.48.226.0/24 flapped 30 times.
# Prefix 179.48.226.0/23 flapped 30 times.
# Prefix 2a05:4140:3f0::/44 flapped 34 times.
# Prefix 195.19.224.0/19 flapped 6 times.
# Prefix 185.37.102.0/24 flapped 6 times.
# Prefix 185.37.103.0/24 flapped 6 times.
# Prefix 2804:540:4000::/35 flapped 14 times.
# Prefix 2001:7a0::/32 flapped 22 times.
# Prefix 2607:6000:d00::/40 flapped 70 times.
# Prefix 2a02:28:7::/48 flapped 20 times.
# Prefix 2a03:7204::/32 flapped 10 times.
# Prefix 2a0e:eac0:2020::/48 flapped 20 times.
# Prefix 2a02:28:d::/48 flapped 20 times.
# Prefix 2a03:6507::/32 flapped 8 times.
# Prefix 2a03:7203::/32 flapped 10 times.
# Prefix 130.137.89.0/24 flapped 45 times.
# Prefix 2a02:28:a::/48 flapped 16 times.
# Prefix 2a00:1fa2:baf0::/44 flapped 16 times.
# Prefix 2a00:1fa2:80c0::/48 flapped 16 times.
# Prefix 2a03:6504::/32 flapped 8 times.
# Prefix 130.137.79.0/24 flapped 47 times.
# Prefix 209.22.67.0/24 flapped 135 times.
# Prefix 209.22.66.0/24 flapped 135 times.
# Prefix 130.137.90.0/24 flapped 45 times.
# Prefix 38.50.197.0/24 flapped 21 times.
# Prefix 102.164.224.0/22 flapped 47 times.
# Prefix 205.65.116.0/24 flapped 14 times.
# Prefix 205.65.136.0/22 flapped 14 times.
# Prefix 2a05:4140:313::/48 flapped 125 times.
# Prefix 2a05:4140:311::/48 flapped 125 times.
# Prefix 2a05:4140:305::/48 flapped 123 times.
# Prefix 205.65.119.0/24 flapped 12 times.
# Prefix 2604:1740::/32 flapped 39 times.
# Prefix 130.137.85.0/24 flapped 37 times.
# Prefix 138.185.242.165/32 flapped 3 times.
# Prefix 2001:c10:ff14::/48 flapped 3 times.
# Prefix 2001:df1:7fc0::/48 flapped 3 times.
# Prefix 2001:df1:280::/48 flapped 3 times.
# Prefix 2001:df0:c8::/48 flapped 3 times.
# Prefix 2001:df7:2980::/48 flapped 3 times.
# Prefix 2001:df1:aac0::/48 flapped 3 times.
# Prefix 2001:e48:3122::/48 flapped 3 times.
# Prefix 2001:e48:41::/48 flapped 3 times.
# Prefix 2001:e48:1180::/48 flapped 3 times.
# Prefix 2001:e48:81::/48 flapped 3 times.
# Prefix 2001:e48:2144::/48 flapped 3 times.
# Prefix 2001:df7:6800:1000::/52 flapped 5 times.
# Prefix 2001:df0:62:8895::/64 flapped 3 times.
# Prefix 2001:e48:44:4::/64 flapped 3 times.
# Prefix 2001:e48:80:1014::/64 flapped 3 times.
# Prefix 2001:e48:80:1010::/64 flapped 3 times.
# Prefix 2001:e48:40:5::/64 flapped 3 times.
# Prefix 2001:e48:11:c::/64 flapped 3 times.
# Prefix 2001:e48:11:1013::/64 flapped 3 times.
# Prefix 2001:e48:11:7::/64 flapped 3 times.
# Prefix 2001:e48:11:1012::/64 flapped 3 times.
# Prefix 2001:e48:44:20::/64 flapped 3 times.
# Prefix 2001:e48:11:100f::/64 flapped 3 times.
# Prefix 2001:e48:33:1008::/64 flapped 3 times.
# Prefix 2001:e48:11:1009::/64 flapped 3 times.
# Prefix 2001:e48:11:1014::/64 flapped 3 times.
# Prefix 2001:e48:122:1a::/64 flapped 3 times.
# Prefix 2001:df7:6800:1181::/64 flapped 3 times.
# Prefix 2001:e48:44:13::/64 flapped 3 times.
# Prefix 130.137.108.0/24 flapped 61 times.
# Prefix 110.172.136.0/24 flapped 20 times.
# Prefix 2001:4479:9600:7000::/56 flapped 5 times.
# Prefix 2801:0:330::/48 flapped 50 times.
# Prefix 177.70.30.0/24 flapped 10 times.
# Prefix 2a10:cc45:4c5::/48 flapped 19 times.
# Prefix 2a10:cc45:53f::/48 flapped 21 times.
# Prefix 2406:840:f895::/48 flapped 74 times.
# Prefix 2a10:cc45:6a3::/48 flapped 19 times.
# Prefix 2a10:cc45:4da::/48 flapped 15 times.
# Prefix 116.199.172.0/24 flapped 22 times.
# Prefix 116.199.170.0/24 flapped 20 times.
# Prefix 116.199.175.0/24 flapped 18 times.
# Prefix 116.199.171.0/24 flapped 20 times.
# Prefix 116.199.168.0/24 flapped 22 times.
# Prefix 116.199.169.0/24 flapped 20 times.
# Prefix 103.102.70.0/24 flapped 20 times.
# Prefix 116.199.174.0/24 flapped 18 times.
# Prefix 103.134.8.0/24 flapped 20 times.
# Prefix 103.102.71.0/24 flapped 22 times.
# Prefix 103.107.63.0/24 flapped 20 times.
# Prefix 103.134.9.0/24 flapped 20 times.
# Prefix 103.134.11.0/24 flapped 20 times.
# Prefix 103.134.10.0/24 flapped 20 times.
# Prefix 2a10:cc45:7c1::/48 flapped 19 times.
# Prefix 2a10:cc45:670::/48 flapped 13 times.
# Prefix 2a12:dd47:c24b::/48 flapped 8 times.
# Prefix 2a12:dd47:c200::/48 flapped 8 times.
# Prefix 2a12:dd47:c293::/48 flapped 8 times.
# Prefix 2a12:dd47:c2b5::/48 flapped 8 times.
# Prefix 2a12:dd47:c219::/48 flapped 8 times.
# Prefix 2a12:dd47:c233::/48 flapped 8 times.
# Prefix 2a12:dd47:c241::/48 flapped 8 times.
# Prefix 2a12:dd47:c246::/48 flapped 8 times.
# Prefix 2a12:dd47:c2cd::/48 flapped 8 times.
# Prefix 2a12:dd47:c2cc::/48 flapped 8 times.
# Prefix 2a12:dd47:c2bc::/48 flapped 8 times.
# Prefix 2a12:dd47:c2d1::/48 flapped 8 times.
# Prefix 2a12:dd47:c2de::/48 flapped 8 times.
# Prefix 2a12:dd47:c28e::/48 flapped 17 times.
# Prefix 2a12:dd47:c2ea::/48 flapped 17 times.
# Prefix 2a12:dd47:c210::/48 flapped 17 times.
# Prefix 2a12:dd47:c2db::/48 flapped 17 times.
# Prefix 2a12:dd47:c20a::/48 flapped 17 times.
# Prefix 2a12:dd47:c2ef::/48 flapped 17 times.
# Prefix 2a12:dd47:c20f::/48 flapped 17 times.
# Prefix 2a12:dd47:c20c::/48 flapped 17 times.
# Prefix 2a12:dd47:c20d::/48 flapped 8 times.
# Prefix 2a12:dd47:c277::/48 flapped 8 times.
# Prefix 2a12:dd47:c299::/48 flapped 8 times.
# Prefix 2a12:dd47:c2b7::/48 flapped 8 times.
# Prefix 2a12:dd47:c2d3::/48 flapped 8 times.
# Prefix 2a12:dd47:c2d8::/48 flapped 8 times.
# Prefix 2a12:dd47:c2ec::/48 flapped 8 times.
# Prefix 2a12:dd47:c260::/48 flapped 17 times.
# Prefix 2a12:dd47:c226::/48 flapped 17 times.
# Prefix 2a10:cc45:71e::/48 flapped 21 times.
# Prefix 2a10:cc45:55e::/48 flapped 15 times.
# Prefix 205.98.64.0/20 flapped 12 times.
# Prefix 2a10:cc45:6ea::/48 flapped 21 times.
# Prefix 2a10:cc45:5c9::/48 flapped 19 times.
# Prefix 2a10:cc45:6bc::/48 flapped 17 times.
# Prefix 2a10:cc45:75b::/48 flapped 21 times.
# Prefix 2a10:cc45:6ec::/48 flapped 21 times.
# Prefix 2a10:cc45:68c::/48 flapped 21 times.
# Prefix 2a10:cc45:766::/48 flapped 23 times.
# Prefix 2a10:cc45:6f6::/48 flapped 17 times.
# Prefix 130.137.118.0/24 flapped 53 times.
# Prefix 2a10:cc45:709::/48 flapped 23 times.
# Prefix 2a10:cc45:462::/48 flapped 25 times.
# Prefix 2a10:cc45:7dd::/48 flapped 17 times.
# Prefix 2a10:cc45:7a8::/48 flapped 17 times.
# Prefix 2a10:cc45:6f2::/48 flapped 19 times.
# Prefix 2a10:cc45:6ad::/48 flapped 21 times.
# Prefix 2a10:cc45:746::/48 flapped 19 times.
# Prefix 2a10:cc45:62a::/48 flapped 19 times.
# Prefix 2a10:cc45:73c::/48 flapped 19 times.
# Prefix 2a10:cc45:640::/48 flapped 23 times.
# Prefix 2a10:cc45:501::/48 flapped 23 times.
# Prefix 103.102.250.0/24 flapped 18 times.
# Prefix 2a10:cc45:74c::/48 flapped 19 times.
# Prefix 2a10:cc45:645::/48 flapped 19 times.
# Prefix 2a10:cc45:6db::/48 flapped 17 times.
# Prefix 2a10:cc45:477::/48 flapped 17 times.
# Prefix 2a10:cc45:765::/48 flapped 17 times.
# Prefix 2a10:cc45:69f::/48 flapped 19 times.
# Prefix 2a10:cc45:49b::/48 flapped 19 times.
# Prefix 2a10:cc45:484::/48 flapped 21 times.
# Prefix 2a10:cc45:70f::/48 flapped 17 times.
# Prefix 2a10:cc45:779::/48 flapped 19 times.
# Prefix 2a10:cc45:40f::/48 flapped 18 times.
# Prefix 2a10:cc45:50a::/48 flapped 18 times.
# Prefix 2a10:cc45:4d1::/48 flapped 18 times.
# Prefix 2a10:cc45:5ad::/48 flapped 19 times.
# Prefix 2a10:cc45:609::/48 flapped 21 times.
# Prefix 2a10:cc45:697::/48 flapped 21 times.
# Prefix 2a10:cc45:48c::/48 flapped 21 times.
# Prefix 2a10:cc45:5e1::/48 flapped 19 times.
# Prefix 2a10:cc45:460::/48 flapped 21 times.
# Prefix 2a10:cc45:72f::/48 flapped 19 times.
# Prefix 2a10:cc45:46b::/48 flapped 16 times.
# Prefix 2a10:cc45:52b::/48 flapped 18 times.
# Prefix 2a10:cc45:4e4::/48 flapped 19 times.
# Prefix 45.168.250.0/24 flapped 7 times.
# Prefix 179.0.69.0/24 flapped 7 times.
# Prefix 167.250.163.0/24 flapped 7 times.
# Prefix 130.137.80.0/24 flapped 57 times.
# Prefix 2a05:4140:6::/48 flapped 18 times.
# Prefix 2001:67c:2994::/48 flapped 15 times.
# Prefix 2406:840:f890::/48 flapped 88 times.
# Prefix 2804:14c:5d36::/48 flapped 10 times.
# Prefix 205.65.144.0/22 flapped 6 times.
# Prefix 2801:11c:c0::/44 flapped 4 times.
# Prefix 2001:df6:7980::/48 flapped 16 times.
# Prefix 185.65.34.0/23 flapped 23 times.
# Prefix 189.113.14.0/24 flapped 14 times.
# Prefix 2803:6601:c000::/37 flapped 6 times.
# Prefix 138.157.224.0/23 flapped 77 times.
# Prefix 205.109.26.0/23 flapped 71 times.
# Prefix 2001:dd8:25::/48 flapped 13 times.
# Prefix 2602:fc09:bb::/48 flapped 12 times.
# Prefix 2602:fc09:cc::/48 flapped 12 times.
# Prefix 2602:fc09:dd::/48 flapped 12 times.
# Prefix 2602:fc09:aa::/48 flapped 12 times.
# Prefix 2801:1f0:4022::/47 flapped 5 times.
# Prefix 2a04:4e42:5a::/48 flapped 15 times.
# Prefix 2800:800:6f0::/44 flapped 4 times.
# Prefix 2804:4140::/34 flapped 4 times.
# Prefix 2800:e0::/28 flapped 4 times.
# Prefix 2801:129::/44 flapped 4 times.
# Prefix 2804:2ce8::/32 flapped 16 times.
# Prefix 198.217.123.0/24 flapped 8 times.
# Prefix 198.217.124.0/24 flapped 8 times.
# Prefix 130.137.127.0/24 flapped 65 times.
# Prefix 193.10.255.0/24 flapped 30 times.
# Prefix 2406:840:380::/48 flapped 4 times.
# Prefix 2406:840:4380::/47 flapped 4 times.
# ...
# Prefix 2a10:cc45:5ef::/48 flapped 15 times.
# Prefix 2a10:cc45:72b::/48 flapped 15 times.
# Prefix 2a10:cc45:77b::/48 flapped 15 times.
# Prefix 2a10:cc45:71f::/48 flapped 13 times.
# Prefix 2a10:cc45:5b8::/48 flapped 13 times.
# Prefix 2a10:cc45:4dc::/48 flapped 17 times.
# Prefix 164.163.239.0/24 flapped 7 times.
# Prefix 37.236.173.0/24 flapped 4 times.
# Prefix 2a10:cc45:6e9::/48 flapped 13 times.
# Prefix 164.163.237.0/24 flapped 11 times.
# Prefix 2a00:5540:386::/48 flapped 23 times.
# Prefix 2804:4580:301::/48 flapped 6 times.
# Prefix 154.176.0.0/22 flapped 3 times.
# Prefix 45.140.146.0/24 flapped 4 times.
# Prefix 103.187.88.0/24 flapped 17 times.
# Prefix 103.187.89.0/24 flapped 15 times.
# Prefix 124.153.25.0/24 flapped 22 times.
# Prefix 2804:4040::/32 flapped 3 times.
# Prefix 144.36.50.0/24 flapped 6 times.
# Prefix 189.113.8.0/24 flapped 16 times.
# Prefix 101.141.249.0/24 flapped 3 times.
# Prefix 190.103.121.0/24 flapped 18 times.
# Prefix 207.235.114.0/24 flapped 4 times.
# Prefix 177.55.69.0/24 flapped 6 times.
# Prefix 37.239.110.0/23 flapped 4 times.
# Prefix 37.238.200.0/24 flapped 4 times.
# Prefix 37.239.96.0/24 flapped 4 times.
# Prefix 37.236.212.0/24 flapped 4 times.
# Prefix 37.239.214.0/24 flapped 4 times.
# Prefix 199.165.17.0/24 flapped 6 times.
# Prefix 199.165.16.0/20 flapped 6 times.
# Prefix 240e:978:4916::/48 flapped 11 times.
# Prefix 38.153.51.0/24 flapped 16 times.
# Prefix 240e:978:49ac::/48 flapped 9 times.
# Prefix 240e:978:492f::/48 flapped 17 times.
# Prefix 163.121.10.0/24 flapped 26 times.
# Prefix 214.57.8.0/24 flapped 13 times.
# Prefix 2804:60a0:8000::/34 flapped 21 times.
# Prefix 45.181.112.0/24 flapped 13 times.
# Prefix 2a10:cc45:527::/48 flapped 15 times.
# Prefix 2a10:cc45:535::/48 flapped 19 times.
# Prefix 2a10:cc45:608::/48 flapped 15 times.
# Prefix 2a10:cc45:52e::/48 flapped 15 times.
# Prefix 2a10:cc45:6a5::/48 flapped 15 times.
# Prefix 2a10:cc45:67e::/48 flapped 15 times.
# Prefix 2a10:cc45:6e4::/48 flapped 15 times.
# Prefix 2a10:cc45:643::/48 flapped 15 times.
# Prefix 2a10:cc45:50f::/48 flapped 17 times.
# Prefix 2801:80:3840::/48 flapped 23 times.
# Prefix 2a10:cc45:520::/48 flapped 15 times.
# Prefix 45.160.69.0/24 flapped 13 times.
# Prefix 45.160.70.0/24 flapped 15 times.
# Prefix 45.160.68.0/23 flapped 15 times.
# Prefix 45.160.70.0/23 flapped 15 times.
# Prefix 45.160.68.0/22 flapped 15 times.
# Prefix 45.160.68.0/24 flapped 7 times.
# Prefix 45.160.71.0/24 flapped 15 times.
# Prefix 2a10:cc45:681::/48 flapped 17 times.
# Prefix 2a10:cc45:523::/48 flapped 15 times.
# Prefix 2a10:cc45:514::/48 flapped 13 times.
# Prefix 2a10:cc45:5d3::/48 flapped 17 times.
# Prefix 2a10:cc45:718::/48 flapped 17 times.
# Prefix 2a10:cc45:6d3::/48 flapped 17 times.
# Prefix 2a10:cc45:4a4::/48 flapped 17 times.
# Prefix 2a10:cc45:736::/48 flapped 17 times.
# Prefix 2a10:cc45:7bb::/48 flapped 17 times.
# Prefix 2a10:cc45:54e::/48 flapped 17 times.
# Prefix 2a10:cc45:65b::/48 flapped 17 times.
# Prefix 2a10:cc45:545::/48 flapped 17 times.
# Prefix 2a10:cc45:5f8::/48 flapped 15 times.
# Prefix 2a10:cc45:75c::/48 flapped 11 times.
# Prefix 2a10:cc45:56a::/48 flapped 17 times.
# Prefix 2a10:cc45:77d::/48 flapped 19 times.
# Prefix 2001:559:223::/48 flapped 18 times.
# Prefix 187.85.192.0/22 flapped 14 times.
# Prefix 131.0.84.0/22 flapped 16 times.
# Prefix 186.193.112.0/22 flapped 14 times.
# Prefix 177.84.180.0/22 flapped 6 times.
# Prefix 177.84.176.0/22 flapped 6 times.
# Prefix 177.84.176.0/21 flapped 6 times.
# Prefix 179.107.6.0/23 flapped 6 times.
# Prefix 179.107.0.0/22 flapped 6 times.
# Prefix 179.107.4.0/23 flapped 6 times.
# Prefix 186.194.224.0/21 flapped 6 times.
# Prefix 186.194.224.0/22 flapped 6 times.
# Prefix 186.193.112.0/21 flapped 6 times.
# Prefix 186.193.120.0/22 flapped 6 times.
# Prefix 186.194.232.0/22 flapped 6 times.
# Prefix 187.87.64.0/22 flapped 6 times.
# Prefix 187.87.68.0/22 flapped 6 times.
# Prefix 186.219.96.0/22 flapped 6 times.
# Prefix 186.219.100.0/22 flapped 6 times.
# Prefix 186.219.96.0/20 flapped 6 times.
# Prefix 187.87.72.0/21 flapped 6 times.
# Prefix 187.87.76.0/22 flapped 6 times.
# Prefix 189.51.152.0/23 flapped 6 times.
# Prefix 200.71.70.0/23 flapped 6 times.
# Prefix 201.76.224.0/19 flapped 6 times.
# Prefix 189.126.182.0/23 flapped 14 times.
# Prefix 189.126.160.0/22 flapped 14 times.
# Prefix 189.113.216.0/21 flapped 6 times.
# Prefix 189.113.216.0/22 flapped 6 times.
# Prefix 190.109.125.0/24 flapped 13 times.
# Prefix 190.109.126.0/24 flapped 13 times.
# Prefix 190.109.124.0/24 flapped 13 times.
# Prefix 154.31.31.0/24 flapped 4 times.
# Prefix 2804:78::/32 flapped 4 times.
# Prefix 70.159.12.0/23 flapped 4 times.
# Prefix 74.174.130.0/24 flapped 4 times.
# Prefix 68.156.127.0/24 flapped 4 times.
# Prefix 74.254.206.0/23 flapped 4 times.
# Prefix 74.174.131.0/24 flapped 4 times.
# Prefix 70.151.33.0/24 flapped 4 times.
# Prefix 12.195.180.0/23 flapped 4 times.
# Prefix 189.39.140.0/24 flapped 7 times.
# Prefix 189.89.29.0/24 flapped 7 times.
# Prefix 189.39.141.0/24 flapped 7 times.
# Prefix 189.89.31.0/24 flapped 7 times.
# Prefix 189.39.143.0/24 flapped 7 times.
# Prefix 201.33.164.0/22 flapped 5 times.
# Prefix 201.33.172.0/22 flapped 3 times.
# Prefix 191.241.68.0/22 flapped 5 times.
# Prefix 191.241.64.0/22 flapped 5 times.
# Prefix 201.33.168.0/22 flapped 3 times.
# Prefix 191.241.76.0/22 flapped 3 times.
# Prefix 201.33.160.0/22 flapped 5 times.
# Prefix 191.241.72.0/22 flapped 5 times.
# Prefix 131.100.198.0/24 flapped 5 times.
# Prefix 170.231.90.0/24 flapped 5 times.
# Prefix 170.231.88.0/24 flapped 5 times.
# Prefix 186.232.210.0/24 flapped 5 times.
# Prefix 170.231.88.0/23 flapped 5 times.
# Prefix 131.100.197.0/24 flapped 3 times.
# Prefix 186.232.212.0/24 flapped 5 times.
# Prefix 186.232.213.0/24 flapped 5 times.
# Prefix 186.232.214.0/24 flapped 5 times.
# Prefix 186.232.209.0/24 flapped 5 times.
# Prefix 170.231.91.0/24 flapped 5 times.
# Prefix 170.231.90.0/23 flapped 5 times.
# Prefix 131.100.198.0/23 flapped 3 times.
# Prefix 177.125.218.0/23 flapped 5 times.
# Prefix 177.91.174.0/23 flapped 3 times.
# Prefix 186.233.190.0/23 flapped 5 times.
# Prefix 177.91.172.0/23 flapped 5 times.
# Prefix 177.125.216.0/23 flapped 5 times.
# Prefix 186.233.188.0/23 flapped 5 times.
# Prefix 187.19.128.0/20 flapped 5 times.
# Prefix 177.37.192.0/20 flapped 5 times.
# Prefix 177.37.160.0/20 flapped 5 times.
# Prefix 177.37.224.0/20 flapped 5 times.
# Prefix 177.37.128.0/20 flapped 3 times.
# Prefix 187.19.208.0/20 flapped 3 times.
# Prefix 187.19.176.0/20 flapped 3 times.
# Prefix 187.19.240.0/20 flapped 3 times.
# Prefix 187.19.144.0/20 flapped 3 times.
# Prefix 189.201.234.0/23 flapped 3 times.
# Prefix 189.201.232.0/23 flapped 3 times.
# Prefix 192.140.39.0/24 flapped 3 times.
# Prefix 192.140.38.0/23 flapped 3 times.
# Prefix 45.56.156.0/24 flapped 3 times.
# Prefix 177.85.64.0/22 flapped 7 times.
# Prefix 177.85.70.0/23 flapped 3 times.
# Prefix 177.85.68.0/23 flapped 3 times.
# Prefix 177.85.68.0/22 flapped 5 times.
# Prefix 177.85.66.0/23 flapped 5 times.
# Prefix 177.39.158.0/23 flapped 3 times.
# Prefix 177.39.156.0/23 flapped 3 times.
# Prefix 191.7.116.0/22 flapped 3 times.
# Prefix 45.169.172.0/24 flapped 3 times.
# Prefix 143.202.92.0/24 flapped 5 times.
# Prefix 201.162.72.0/23 flapped 3 times.
# Prefix 45.230.166.0/23 flapped 3 times.
# Prefix 45.230.164.0/23 flapped 3 times.
# Prefix 189.39.189.0/24 flapped 3 times.
# Prefix 188.241.158.0/24 flapped 12 times.
# Prefix 177.55.71.0/24 flapped 20 times.
# Prefix 2a12:dd47:8161::/48 flapped 8 times.
# Prefix 91.208.197.0/24 flapped 4 times.
# Prefix 2406:840:f90b::/48 flapped 12 times.
# Prefix 2a0e:800:6666::/48 flapped 12 times.
# Prefix 177.70.4.0/24 flapped 13 times.
# Prefix 186.195.12.0/22 flapped 3 times.
# Prefix 213.204.78.0/24 flapped 6 times.
# Prefix 177.37.36.0/22 flapped 18 times.
# Prefix 2001:df6:8e80::/48 flapped 12 times.
# Prefix 2a10:cc45:415::/48 flapped 17 times.
# Prefix 195.19.32.0/19 flapped 24 times.
# Prefix 2a10:cc45:5eb::/48 flapped 11 times.
# Prefix 2a10:cc45:440::/48 flapped 11 times.
# Prefix 2a10:cc45:716::/48 flapped 15 times.
# Prefix 2a10:cc45:500::/48 flapped 11 times.
# Prefix 2a10:cc45:725::/48 flapped 15 times.
# Prefix 2a10:cc45:798::/48 flapped 11 times.
# Prefix 2a10:cc45:5f5::/48 flapped 11 times.
# Prefix 2a10:cc45:606::/48 flapped 19 times.
# Prefix 2a10:cc45:5b1::/48 flapped 19 times.
# Prefix 2a10:cc45:7b7::/48 flapped 19 times.
# Prefix 2a10:cc45:5d8::/48 flapped 11 times.
# Prefix 2a10:cc45:518::/48 flapped 13 times.
# Prefix 2a10:cc45:60c::/48 flapped 11 times.
# Prefix 2a10:cc45:557::/48 flapped 19 times.
# Prefix 2a10:cc45:6a6::/48 flapped 13 times.
# Prefix 2a10:cc45:4ea::/48 flapped 15 times.
# Prefix 2a10:cc45:402::/48 flapped 19 times.
# Prefix 2a10:cc45:5d1::/48 flapped 15 times.
# Prefix 2a10:cc45:732::/48 flapped 11 times.
# Prefix 2a10:cc45:45f::/48 flapped 13 times.
# Prefix 2a10:cc45:659::/48 flapped 11 times.
# Prefix 2a10:cc45:5ce::/48 flapped 15 times.
# Prefix 2a10:cc45:6c4::/48 flapped 15 times.
# Prefix 2a10:cc45:53c::/48 flapped 13 times.
# Prefix 2a06:e881:4800::/48 flapped 8 times.
# Prefix 2a0e:b107:1b94::/48 flapped 4 times.
# Prefix 2a09:4c0:5e0::/48 flapped 6 times.
# Prefix 2a0e:b107:1786::/48 flapped 6 times.
# Prefix 2a0e:b107:bd0::/48 flapped 4 times.
# Prefix 2a10:2f00:10a::/48 flapped 4 times.
# Prefix 2a10:2f00:17b::/48 flapped 14 times.
# Prefix 2a0e:b107:30f::/48 flapped 8 times.
# Prefix 2a0e:b107:861::/48 flapped 6 times.
# Prefix 2a0e:b107:1cf0::/48 flapped 10 times.
# Prefix 2a0e:b107:1a43::/48 flapped 6 times.
# Prefix 2602:feda:be0::/48 flapped 8 times.
# Prefix 2a06:a005:2c2::/48 flapped 14 times.
# Prefix 2a0f:5707:aa5a::/48 flapped 14 times.
# Prefix 2a0f:5707:aa5b::/48 flapped 14 times.
# Prefix 2a0d:2583:ab04::/48 flapped 16 times.
# Prefix 2a0c:b641:16a::/48 flapped 14 times.
# Prefix 2a0e:fd45:2b70::/48 flapped 14 times.
# Prefix 2602:fd50:10f2::/48 flapped 12 times.
# Prefix 2a10:cc45:5e5::/48 flapped 15 times.
# Prefix 213.110.101.0/24 flapped 4 times.
# Prefix 240e:978:493a::/48 flapped 19 times.
# Prefix 109.233.103.0/24 flapped 6 times.
# Prefix 109.233.102.0/24 flapped 6 times.
# Prefix 109.233.101.0/24 flapped 6 times.
# Prefix 109.233.100.0/24 flapped 6 times.
# Prefix 240e:978:493c::/48 flapped 19 times.
# Prefix 240e:978:49bf::/48 flapped 19 times.
# Prefix 196.32.8.0/21 flapped 4 times.
# Prefix 103.157.85.0/24 flapped 4 times.
# Prefix 38.51.156.0/22 flapped 4 times.
# Prefix 31.134.222.0/24 flapped 14 times.
# Prefix 31.134.223.0/24 flapped 14 times.
# Prefix 31.134.218.0/24 flapped 4 times.
# Prefix 2.56.91.0/24 flapped 20 times.
# Prefix 103.166.126.0/23 flapped 20 times.
# Prefix 31.134.217.0/24 flapped 14 times.
# Prefix 31.134.216.0/24 flapped 14 times.
# Prefix 31.134.221.0/24 flapped 6 times.
# Prefix 31.134.219.0/24 flapped 6 times.
# Prefix 168.235.165.0/24 flapped 8 times.
# Prefix 168.235.164.0/24 flapped 18 times.
# Prefix 50.217.139.0/24 flapped 8 times.
# Prefix 179.63.13.0/24 flapped 18 times.
# Prefix 196.2.193.0/24 flapped 17 times.
# Prefix 199.66.170.0/24 flapped 10 times.
# Prefix 187.62.239.0/24 flapped 4 times.
# Prefix 143.141.136.0/21 flapped 20 times.
# Prefix 214.4.94.0/24 flapped 20 times.
# Prefix 204.222.249.0/24 flapped 20 times.
# Prefix 131.18.98.0/23 flapped 20 times.
# Prefix 204.222.248.0/24 flapped 20 times.
# Prefix 143.141.128.0/22 flapped 20 times.
# Prefix 41.79.220.0/24 flapped 14 times.
# Prefix 89.164.252.0/24 flapped 13 times.
# Prefix 190.196.246.0/24 flapped 15 times.
# Prefix 2804:14c:5d83::/48 flapped 10 times.
# Prefix 193.161.205.0/24 flapped 22 times.
# Prefix 45.93.93.0/24 flapped 6 times.
# Prefix 2a10:cc45:6c1::/48 flapped 19 times.
# Prefix 2a10:cc45:6a1::/48 flapped 17 times.
# Prefix 2a10:cc45:53a::/48 flapped 19 times.
# Prefix 2a10:cc45:57f::/48 flapped 13 times.
# Prefix 2a10:cc45:547::/48 flapped 15 times.
# Prefix 2a10:cc45:5d4::/48 flapped 14 times.
# Prefix 2a10:cc45:750::/48 flapped 23 times.
# Prefix 2a10:cc45:4bb::/48 flapped 21 times.
# Prefix 2a10:cc45:5f2::/48 flapped 13 times.
# Prefix 2a10:cc45:498::/48 flapped 15 times.
# Prefix 2a10:cc45:401::/48 flapped 15 times.
# Prefix 2a10:cc45:783::/48 flapped 15 times.
# Prefix 2a10:cc45:730::/48 flapped 19 times.
# Prefix 2a10:cc45:65d::/48 flapped 17 times.
# Prefix 2a10:cc45:563::/48 flapped 15 times.
# Prefix 23.178.176.0/24 flapped 21 times.
# Prefix 23.178.177.0/24 flapped 21 times.
# Prefix 2a10:cc45:478::/48 flapped 13 times.
# Prefix 2a10:cc45:47b::/48 flapped 21 times.
# Prefix 23.178.178.0/24 flapped 21 times.
# Prefix 205.72.96.0/20 flapped 13 times.
# Prefix 2a10:cc45:447::/48 flapped 13 times.
# Prefix 185.191.204.0/24 flapped 8 times.
# Prefix 2a10:cc45:517::/48 flapped 21 times.
# Prefix 2a10:cc45:40d::/48 flapped 13 times.
# Prefix 2a10:cc45:7ab::/48 flapped 19 times.
# Prefix 2a10:cc45:548::/48 flapped 19 times.
# Prefix 2a10:cc45:5c4::/48 flapped 17 times.
# Prefix 2a10:cc45:6d8::/48 flapped 15 times.
# Prefix 2a10:cc45:71b::/48 flapped 17 times.
# Prefix 2a10:cc45:6ed::/48 flapped 19 times.
# Prefix 194.76.252.0/24 flapped 6 times.
# Prefix 192.31.177.0/24 flapped 18 times.
# Prefix 199.89.147.0/24 flapped 10 times.
# Prefix 2a02:d107:f001::/48 flapped 4 times.
# Prefix 138.117.231.0/24 flapped 19 times.
# Prefix 138.117.229.0/24 flapped 19 times.
# Prefix 2803:bee0:4000::/36 flapped 11 times.
# Prefix 2803:bee0:4000::/48 flapped 11 times.
# Prefix 2803:bee0::/36 flapped 13 times.
# Prefix 2803:bee0::/48 flapped 7 times.
# Prefix 2602:ff0d::/40 flapped 6 times.
# Prefix 103.244.142.0/24 flapped 4 times.
# Prefix 2a02:cb80:4101::/48 flapped 8 times.
# Prefix 2a02:cb80:4100::/48 flapped 8 times.
# Prefix 51.36.171.0/24 flapped 6 times.
# Prefix 51.36.140.0/23 flapped 6 times.
# Prefix 51.36.180.0/23 flapped 6 times.
# Prefix 51.36.170.0/24 flapped 6 times.
# Prefix 77.223.242.0/23 flapped 6 times.
# Prefix 51.39.228.0/24 flapped 6 times.
# Prefix 95.178.24.0/21 flapped 6 times.
# Prefix 51.39.130.0/23 flapped 6 times.
# Prefix 51.39.150.0/23 flapped 6 times.
# Prefix 51.36.160.0/23 flapped 6 times.
# Prefix 51.39.192.0/23 flapped 6 times.
# Prefix 51.39.128.0/23 flapped 6 times.
# Prefix 51.39.246.0/23 flapped 6 times.
# Prefix 51.39.179.0/24 flapped 6 times.
# Prefix 51.36.168.0/23 flapped 6 times.
# Prefix 51.36.250.0/23 flapped 6 times.
# Prefix 77.223.244.0/23 flapped 6 times.
# Prefix 51.39.227.0/24 flapped 6 times.
# Prefix 51.39.194.0/23 flapped 6 times.
# Prefix 51.36.154.0/23 flapped 6 times.
# Prefix 51.39.52.0/23 flapped 6 times.
# Prefix 51.39.156.0/23 flapped 6 times.
# Prefix 51.36.20.0/23 flapped 6 times.
# Prefix 51.39.226.0/24 flapped 6 times.
# Prefix 51.39.54.0/23 flapped 6 times.
# Prefix 51.39.22.0/23 flapped 6 times.
# Prefix 51.39.244.0/23 flapped 6 times.
# Prefix 51.36.128.0/23 flapped 6 times.
# Prefix 51.36.228.0/23 flapped 6 times.
# Prefix 51.39.152.0/23 flapped 6 times.
# Prefix 51.36.24.0/23 flapped 6 times.
# Prefix 51.36.142.0/23 flapped 6 times.
# Prefix 51.36.150.0/23 flapped 6 times.
# Prefix 51.36.182.0/23 flapped 6 times.
# Prefix 51.36.130.0/23 flapped 6 times.
# Prefix 103.126.4.0/24 flapped 8 times.
# Prefix 205.98.128.0/20 flapped 20 times.
# Prefix 240e:978:4978::/48 flapped 13 times.
# Prefix 197.231.88.0/22 flapped 17 times.
# Prefix 240e:978:49fd::/48 flapped 13 times.
# Prefix 240e:978:49d9::/48 flapped 15 times.
# Prefix 177.70.10.0/24 flapped 7 times.
# Prefix 37.238.18.0/24 flapped 22 times.
# Prefix 37.236.168.0/24 flapped 34 times.
# Prefix 37.239.100.0/24 flapped 24 times.
# Prefix 37.236.110.0/24 flapped 32 times.
# Prefix 37.237.70.0/24 flapped 22 times.
# Prefix 37.238.109.0/24 flapped 36 times.
# Prefix 37.236.184.0/24 flapped 24 times.
# Prefix 37.238.0.0/24 flapped 32 times.
# Prefix 37.236.87.0/24 flapped 34 times.
# Prefix 37.236.200.0/23 flapped 32 times.
# Prefix 37.239.102.0/24 flapped 22 times.
# Prefix 37.238.96.0/24 flapped 32 times.
# Prefix 37.236.67.0/24 flapped 22 times.
# Prefix 37.238.215.0/24 flapped 24 times.
# Prefix 37.238.38.0/24 flapped 24 times.
# Prefix 37.236.41.0/24 flapped 24 times.
# Prefix 37.236.198.0/24 flapped 22 times.
# Prefix 37.239.224.0/24 flapped 22 times.
# Prefix 37.239.27.0/24 flapped 22 times.
# Prefix 2a06:a005:60::/44 flapped 6 times.
# Prefix 2a12:6f47::/32 flapped 6 times.
# Prefix 2a06:a005:70::/44 flapped 6 times.
# Prefix 178.175.131.0/24 flapped 9 times.
# Prefix 103.239.161.0/24 flapped 22 times.
# Prefix 101.99.81.0/24 flapped 17 times.
# Prefix 205.107.129.0/24 flapped 4 times.
# Prefix 2406:840:921f::/48 flapped 4 times.
# Prefix 102.68.125.0/24 flapped 18 times.
# Prefix 102.67.152.0/24 flapped 6 times.

# %% [markdown]
# # Monitoring AS Path Changes

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def monitor_as_path_changes(from_time, until_time, target_prefixes=None, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    prefix_as_paths = defaultdict(set)

    for rec in stream.records():
        for elem in rec:
            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            # If target_prefixes are specified, filter prefixes
            if target_prefixes and prefix not in target_prefixes:
                continue

            as_path_str = elem.fields.get('as-path', "")
            as_path = tuple(as_path_str.split())

            if as_path:
                if as_path not in prefix_as_paths[prefix]:
                    print(f"New AS path for {prefix}: {' '.join(as_path)}")
                    prefix_as_paths[prefix].add(as_path)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 02:00:00"
target_prefixes = ['192.0.2.0/24', '198.51.100.0/24']
monitor_as_path_changes(from_time, until_time, target_prefixes)

# %% [markdown]
# # Analyzing Community Attributes

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def analyze_communities(from_time, until_time, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    community_counts = defaultdict(int)

    for rec in stream.records():
        for elem in rec:
            communities = elem.fields.get('communities', [])
            for community in communities:
                community_str = f"{community[0]}:{community[1]}"
                community_counts[community_str] += 1

    print("Community Attributes:")
    for community, count in community_counts.items():
        print(f"{community}: {count}")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
analyze_communities(from_time, until_time)

# %% [markdown]
# # Detecting BGP Hijacks

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def detect_bgp_hijacks(from_time, until_time, prefix_origin_mapping, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    hijack_events = []

    for rec in stream.records():
        for elem in rec:
            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            # Check if the prefix is one we're monitoring
            if prefix not in prefix_origin_mapping:
                continue

            as_path_str = elem.fields.get('as-path', "")
            as_path = as_path_str.split()

            if not as_path:
                continue

            origin_asn = as_path[-1]
            expected_asn = prefix_origin_mapping[prefix]

            if origin_asn != expected_asn:
                event = {
                    'timestamp': datetime.utcfromtimestamp(elem.time).isoformat(),
                    'prefix': prefix,
                    'expected_origin': expected_asn,
                    'observed_origin': origin_asn,
                    'as_path': as_path_str,
                    'peer_asn': elem.peer_asn,
                    'collector': rec.collector
                }
                hijack_events.append(event)
                print(f"Possible hijack detected for {prefix}: expected {expected_asn}, observed {origin_asn}")

    # Output the hijack events
    print("\nHijack Events:")
    for event in hijack_events:
        print(event)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
# Define the expected origin ASNs for prefixes
prefix_origin_mapping = {
    '192.0.2.0/24': '64500',
    '198.51.100.0/24': '64501',
    # Add more prefixes and their expected origin ASNs as needed
}
detect_bgp_hijacks(from_time, until_time, prefix_origin_mapping)
# Out:
# Hijack Events:

# %% [markdown]
# # Analyzing AS Path Prepending

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def analyze_as_path_prepending(from_time, until_time, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    prepending_counts = defaultdict(int)

    for rec in stream.records():
        for elem in rec:
            if elem.type != 'A':
                continue

            as_path_str = elem.fields.get('as-path', "")
            as_path = as_path_str.split()

            if not as_path:
                continue

            # Count AS prepending
            last_asn = None
            consecutive_count = 1
            for asn in as_path:
                if asn == last_asn:
                    consecutive_count += 1
                else:
                    if consecutive_count > 1:
                        prepending_counts[last_asn] += consecutive_count - 1
                    consecutive_count = 1
                last_asn = asn

            # Check for prepending at the end of the path
            if consecutive_count > 1 and last_asn:
                prepending_counts[last_asn] += consecutive_count - 1

    # Report top ASes performing prepending
    print("AS Path Prepending Counts:")
    for asn, count in sorted(prepending_counts.items(), key=lambda x: x[1], reverse=True):
        print(f"ASN {asn}: {count} times")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
analyze_as_path_prepending(from_time, until_time)
# Out:
# AS Path Prepending Counts:
# ASN 24534: 47624 times
# ASN 4837: 22651 times
# ASN 131219: 21904 times
# ASN 264525: 10745 times
# ASN 53115: 9075 times
# ASN 8717: 8140 times
# ASN 138211: 7876 times
# ASN 45582: 7506 times
# ASN 8100: 7102 times
# ASN 39010: 6346 times
# ASN 2046: 5655 times
# ASN 61591: 4366 times
# ASN 132556: 4364 times
# ASN 13904: 4150 times
# ASN 138489: 4110 times
# ASN 14080: 3929 times
# ASN 264911: 3285 times
# ASN 263774: 3086 times
# ASN 8359: 2907 times
# ASN 15638: 1 times
# ASN 15321: 1 times
# ASN 269898: 1 times
# ASN 262725: 1 times
# ASN 4804: 1 times
# ASN 16342: 1 times
# ASN 12956: 1 times
# ASN 19114: 1 times
# ASN 264592: 1 times
# ASN 141047: 1 times
# ASN 395271: 1 times
# ASN 17314: 1 times
# ASN 264368: 1 times
# ASN 267664: 1 times
# ASN 268858: 1 times
# ASN 262381: 1 times
# ASN 11608: 1 times
# ASN 133929: 1 times
# ASN 9905: 1 times
# ASN 142325: 1 times
# ASN 28173: 1 times
# ASN 138543: 1 times
# ASN 8764: 1 times
# ASN 38785: 1 times
# ASN 3267: 1 times
# ASN 269276: 1 times
# ASN 52613: 1 times
# ASN 204170: 1 times
# ASN 136841: 1 times
# ASN 271201: 1 times
# ASN 268213: 1 times
# ASN 27851: 1 times
# ASN 52571: 1 times
# ASN 61844: 1 times
# ASN 268503: 1 times
# ASN 264974: 1 times
# ASN 270441: 1 times
# ASN 269104: 1 times
# ASN 4385: 1 times
# ASN 265290: 1 times
# ASN 149489: 1 times
# ASN 264459: 1 times
# ASN 213373: 1 times
# ASN 267561: 1 times
# ASN 397956: 1 times

# %% [markdown]
# # Monitoring MOAS (Multiple Origin AS) Conflicts

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def monitor_moas_conflicts(from_time, until_time, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    prefix_origins = defaultdict(set)
    moas_conflicts = defaultdict(set)

    for rec in stream.records():
        for elem in rec:
            if elem.type != 'A':
                continue

            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            as_path_str = elem.fields.get('as-path', "")
            as_path = as_path_str.split()

            if not as_path:
                continue

            origin_asn = as_path[-1]
            prefix_origins[prefix].add(origin_asn)

            if len(prefix_origins[prefix]) > 1:
                moas_conflicts[prefix] = prefix_origins[prefix]

    # Report MOAS conflicts
    print("MOAS Conflicts Detected:")
    for prefix, origins in moas_conflicts.items():
        origins_list = ', '.join(origins)
        print(f"Prefix {prefix} announced by ASNs: {origins_list}")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 02:00:00"
monitor_moas_conflicts(from_time, until_time)
# Out:
# MOAS Conflicts Detected:
# Prefix 2001:dc7:fffe::/48 announced by ASNs: 24406, 24151
# Prefix 2001:dc7:ffff::/48 announced by ASNs: 24406, 24151
# Prefix 2001:dc7::/48 announced by ASNs: 24406, 24151
# Prefix 2001:dc7:1000::/48 announced by ASNs: 24406, 24151
# Prefix 2001:dc7:3::/48 announced by ASNs: 24409, 24406
# Prefix 2001:dc7:fffb::/48 announced by ASNs: 24409, 24406
# Prefix 240e:978:4984::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:4980::/48 announced by ASNs: 146966, 134756
# Prefix 2407:d340:7129::/48 announced by ASNs: 142031, 61302
# Prefix 2602:808:4002::/48 announced by ASNs: 16509, 398960
# Prefix 41.86.37.0/24 announced by ASNs: 36958, 12491
# Prefix 80.247.145.0/24 announced by ASNs: 12684, 64513
# Prefix 148.252.128.0/19 announced by ASNs: 25135, {25135}
# Prefix 148.252.128.0/23 announced by ASNs: 25135, {25135}
# Prefix 45.172.8.0/24 announced by ASNs: 265705, 267800
# Prefix 240e:978:49bf::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:493c::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:493a::/48 announced by ASNs: 146966, 134756
# Prefix 5.35.174.0/24 announced by ASNs: 61424, 58143
# Prefix 213.238.166.0/24 announced by ASNs: 43260, 209474
# Prefix 185.191.204.0/24 announced by ASNs: 35758, 12400
# Prefix 185.37.239.0/24 announced by ASNs: 200047, 21371
# Prefix 240e:978:49fd::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:4978::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49d9::/48 announced by ASNs: 146966, 134756
# Prefix 112.33.120.0/24 announced by ASNs: 9808, 56040
# Prefix 197.211.8.0/24 announced by ASNs: 37027, 15399
# Prefix 240e:978:49f4::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:492c::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:8005::/48 announced by ASNs: 146966, 134756
# Prefix 108.165.227.0/24 announced by ASNs: 210703, 62240
# Prefix 181.215.65.0/24 announced by ASNs: 210703, 834
# Prefix 102.68.154.0/23 announced by ASNs: 327707, 328443
# Prefix 102.68.155.0/24 announced by ASNs: 327707, 328443
# Prefix 102.68.154.0/24 announced by ASNs: 327707, 328443
# Prefix 207.248.117.0/24 announced by ASNs: 32098, 65011
# Prefix 207.248.116.0/24 announced by ASNs: 32098, 65011
# Prefix 240e:978:1d1c::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49dc::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49c9::/48 announced by ASNs: 146966, 134756
# Prefix 103.88.68.0/23 announced by ASNs: 64924, 132505
# Prefix 240e:978:4934::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49aa::/48 announced by ASNs: 146966, 134756
# Prefix 196.49.6.0/24 announced by ASNs: 327775, 23456
# Prefix 240e:978:4977::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49bd::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:4997::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49df::/48 announced by ASNs: 146966, 134756
# Prefix 240e:978:49d2::/48 announced by ASNs: 146966, 134756
# Prefix 175.158.209.0/24 announced by ASNs: 65255, 10139
# Prefix 103.158.222.0/24 announced by ASNs: 137490, 38230

# %% [markdown]
# # Detecting Bogon Prefix Announcements

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime
import ipaddress

# List of bogon prefixes (simplified example)
BOGON_PREFIXES = [
    ipaddress.ip_network('0.0.0.0/8'),
    ipaddress.ip_network('10.0.0.0/8'),
    ipaddress.ip_network('127.0.0.0/8'),
    ipaddress.ip_network('169.254.0.0/16'),
    ipaddress.ip_network('172.16.0.0/12'),
    ipaddress.ip_network('192.168.0.0/16'),
    ipaddress.ip_network('224.0.0.0/4'),
    ipaddress.ip_network('240.0.0.0/4'),
    # Add IPv6 bogon prefixes as needed
]

def is_bogon(prefix):
    try:
        network = ipaddress.ip_network(prefix)
        for bogon in BOGON_PREFIXES:
            if network.subnet_of(bogon):
                return True
    except ValueError:
        pass
    return False

def detect_bogon_announcements(from_time, until_time, collectors=['route-views.sg']):
    """
    Detects announcements of bogon prefixes.

    :param from_time: Start time for data collection.
    :param until_time: End time for data collection.
    :param collectors: List of collectors to use.
    """
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    bogon_announcements = defaultdict(list)

    for rec in stream.records():
        for elem in rec:
            if elem.type != 'A':
                continue

            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            if is_bogon(prefix):
                timestamp = datetime.utcfromtimestamp(elem.time).isoformat()
                bogon_announcements[prefix].append({
                    'timestamp': timestamp,
                    'peer_asn': elem.peer_asn,
                    'as_path': elem.fields.get('as-path', ""),
                    'collector': rec.collector
                })
                print(f"Bogon prefix announced: {prefix} at {timestamp}")

    # Output bogon announcements
    print("\nBogon Announcements:")
    for prefix, events in bogon_announcements.items():
        print(f"\nPrefix: {prefix}")
        for event in events:
            print(event)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
detect_bogon_announcements(from_time, until_time)

# %% [markdown]
# # Monitoring Prefix De-aggregation

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime
import ipaddress

def monitor_prefix_deaggregation(from_time, until_time, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    super_prefixes = defaultdict(set)
    deaggregation_events = []

    for rec in stream.records():
        for elem in rec:
            if elem.type != 'A':
                continue

            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            try:
                network = ipaddress.ip_network(prefix)
            except ValueError:
                continue

            # Check for super-prefixes
            for supernet_prefix in super_prefixes:
                supernet = ipaddress.ip_network(supernet_prefix)
                if network != supernet and network.subnet_of(supernet):
                    event = {
                        'timestamp': datetime.utcfromtimestamp(elem.time).isoformat(),
                        'super_prefix': supernet_prefix,
                        'more_specific_prefix': prefix,
                        'collector': rec.collector
                    }
                    deaggregation_events.append(event)
                    print(f"De-aggregation detected: {prefix} is a subnet of {supernet_prefix}")
                    break

            # Add the prefix to super_prefixes
            super_prefixes[str(network)] = network

    # Output de-aggregation events
    print("\nDe-aggregation Events:")
    for event in deaggregation_events:
        print(event)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 02:00:00"
monitor_prefix_deaggregation(from_time, until_time)

# %% [markdown]
# # Analyzing MED and Local Preference Attributes

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime
import statistics

def analyze_med_local_pref(from_time, until_time, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    med_values = []
    local_pref_values = []

    for rec in stream.records():
        for elem in rec:
            if elem.type != 'A':
                continue

            update = elem.fields
            med = update.get('med')
            if med is not None:
                try:
                    med_values.append(int(med))
                except ValueError:
                    pass  # Ignore invalid MED values

            local_pref = update.get('local-pref')
            if local_pref is not None:
                try:
                    local_pref_values.append(int(local_pref))
                except ValueError:
                    pass  # Ignore invalid Local Preference values

    # Compute statistics
    if med_values:
        med_avg = statistics.mean(med_values)
        med_min = min(med_values)
        med_max = max(med_values)
        med_stddev = statistics.stdev(med_values) if len(med_values) > 1 else 0
        print("MED Statistics:")
        print(f"Average: {med_avg}, Min: {med_min}, Max: {med_max}, StdDev: {med_stddev}")
    else:
        print("No MED values found.")

    if local_pref_values:
        lp_avg = statistics.mean(local_pref_values)
        lp_min = min(local_pref_values)
        lp_max = max(local_pref_values)
        lp_stddev = statistics.stdev(local_pref_values) if len(local_pref_values) > 1 else 0
        print("\nLocal Preference Statistics:")
        print(f"Average: {lp_avg}, Min: {lp_min}, Max: {lp_max}, StdDev: {lp_stddev}")
    else:
        print("No Local Preference values found.")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
analyze_med_local_pref(from_time, until_time)

# %% [markdown]
# # Analyzing BGP Session Resets

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime, timedelta

def analyze_bgp_session_resets(from_time, until_time, reset_threshold=5, collectors=['route-views.sg']):
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    withdrawal_events = defaultdict(list)
    session_resets = []

    for rec in stream.records():
        for elem in rec:
            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            peer_asn = elem.peer_asn
            timestamp = datetime.utcfromtimestamp(elem.time)

            if elem.type == 'W':
                withdrawal_events[peer_asn].append((timestamp, prefix))

    # Analyze for session resets
    for peer, events in withdrawal_events.items():
        events.sort()
        # Group withdrawals that occur within a short time window (e.g., 1 minute)
        window_start = None
        window_events = []

        for event_time, prefix in events:
            if window_start is None:
                window_start = event_time
                window_events.append((event_time, prefix))
            elif (event_time - window_start) <= timedelta(minutes=1):
                window_events.append((event_time, prefix))
            else:
                if len(window_events) >= reset_threshold:
                    session_resets.append({
                        'peer_asn': peer,
                        'start_time': window_start.isoformat(),
                        'end_time': event_time.isoformat(),
                        'withdrawal_count': len(window_events)
                    })
                    print(f"BGP session reset suspected for peer {peer} between {window_start} and {event_time}")

                # Reset window
                window_start = event_time
                window_events = [(event_time, prefix)]

    # Output session reset events
    print("\nBGP Session Reset Events:")
    for reset in session_resets:
        print(reset)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 03:00:00"
analyze_bgp_session_resets(from_time, until_time)
# Out:
# BGP session reset suspected for peer 24115 between 2023-01-01 00:00:00 and 2023-01-01 00:01:03
# BGP session reset suspected for peer 24115 between 2023-01-01 00:01:03 and 2023-01-01 00:02:04
# BGP session reset suspected for peer 24115 between 2023-01-01 00:02:04 and 2023-01-01 00:03:06
# BGP session reset suspected for peer 24115 between 2023-01-01 00:03:06 and 2023-01-01 00:04:08
# BGP session reset suspected for peer 24115 between 2023-01-01 00:04:08 and 2023-01-01 00:05:10
# BGP session reset suspected for peer 24115 between 2023-01-01 00:05:10 and 2023-01-01 00:06:11
# BGP session reset suspected for peer 24115 between 2023-01-01 00:06:11 and 2023-01-01 00:07:13
# BGP session reset suspected for peer 24115 between 2023-01-01 00:07:13 and 2023-01-01 00:08:23
# BGP session reset suspected for peer 24115 between 2023-01-01 00:08:23 and 2023-01-01 00:09:28
# BGP session reset suspected for peer 24115 between 2023-01-01 00:09:28 and 2023-01-01 00:10:29
# BGP session reset suspected for peer 24115 between 2023-01-01 00:10:29 and 2023-01-01 00:11:34
# BGP session reset suspected for peer 24115 between 2023-01-01 00:11:34 and 2023-01-01 00:12:41
# BGP session reset suspected for peer 24115 between 2023-01-01 00:12:41 and 2023-01-01 00:13:50
# BGP session reset suspected for peer 24115 between 2023-01-01 00:13:50 and 2023-01-01 00:14:51
# BGP session reset suspected for peer 24115 between 2023-01-01 00:14:51 and 2023-01-01 00:15:57
# BGP session reset suspected for peer 24115 between 2023-01-01 00:15:57 and 2023-01-01 00:17:00
# BGP session reset suspected for peer 24115 between 2023-01-01 00:17:00 and 2023-01-01 00:18:05
# BGP session reset suspected for peer 24115 between 2023-01-01 00:18:05 and 2023-01-01 00:19:06
# BGP session reset suspected for peer 24115 between 2023-01-01 00:19:06 and 2023-01-01 00:20:14
# BGP session reset suspected for peer 24115 between 2023-01-01 00:20:14 and 2023-01-01 00:21:15
# BGP session reset suspected for peer 24115 between 2023-01-01 00:21:15 and 2023-01-01 00:22:21
# BGP session reset suspected for peer 24115 between 2023-01-01 00:22:21 and 2023-01-01 00:23:23
# BGP session reset suspected for peer 24115 between 2023-01-01 00:23:23 and 2023-01-01 00:24:30
# BGP session reset suspected for peer 24115 between 2023-01-01 00:24:30 and 2023-01-01 00:25:33
# BGP session reset suspected for peer 24115 between 2023-01-01 00:25:33 and 2023-01-01 00:26:34
# BGP session reset suspected for peer 24115 between 2023-01-01 00:26:34 and 2023-01-01 00:27:40
# BGP session reset suspected for peer 24115 between 2023-01-01 00:27:40 and 2023-01-01 00:28:43
# BGP session reset suspected for peer 24115 between 2023-01-01 00:28:43 and 2023-01-01 00:29:49
# BGP session reset suspected for peer 24115 between 2023-01-01 00:29:49 and 2023-01-01 00:30:58
# BGP session reset suspected for peer 24115 between 2023-01-01 00:30:58 and 2023-01-01 00:32:03
# BGP session reset suspected for peer 24115 between 2023-01-01 00:32:03 and 2023-01-01 00:33:06
# BGP session reset suspected for peer 24115 between 2023-01-01 00:33:06 and 2023-01-01 00:34:17
# BGP session reset suspected for peer 24115 between 2023-01-01 00:34:17 and 2023-01-01 00:35:20
# BGP session reset suspected for peer 24115 between 2023-01-01 00:35:20 and 2023-01-01 00:36:22
# BGP session reset suspected for peer 24115 between 2023-01-01 00:36:22 and 2023-01-01 00:37:24
# BGP session reset suspected for peer 24115 between 2023-01-01 02:56:22 and 2023-01-01 02:57:24
# BGP session reset suspected for peer 24115 between 2023-01-01 02:57:24 and 2023-01-01 02:58:37
# BGP session reset suspected for peer 24115 between 2023-01-01 02:58:37 and 2023-01-01 02:59:38
# BGP session reset suspected for peer 9902 between 2023-01-01 00:00:00 and 2023-01-01 00:01:01
# BGP session reset suspected for peer 9902 between 2023-01-01 00:01:01 and 2023-01-01 00:02:02
# BGP session reset suspected for peer 9902 between 2023-01-01 00:02:02 and 2023-01-01 00:03:06
# BGP session reset suspected for peer 9902 between 2023-01-01 00:03:06 and 2023-01-01 00:04:11
# BGP session reset suspected for peer 9902 between 2023-01-01 00:04:11 and 2023-01-01 00:05:15
# BGP session reset suspected for peer 9902 between 2023-01-01 00:05:15 and 2023-01-01 00:06:20
# BGP session reset suspected for peer 9902 between 2023-01-01 00:06:20 and 2023-01-01 00:07:23
# BGP session reset suspected for peer 9902 between 2023-01-01 00:07:23 and 2023-01-01 00:08:25
# BGP session reset suspected for peer 9902 between 2023-01-01 00:08:25 and 2023-01-01 00:09:26
# BGP session reset suspected for peer 9902 between 2023-01-01 00:09:26 and 2023-01-01 00:10:27
# BGP session reset suspected for peer 9902 between 2023-01-01 00:10:27 and 2023-01-01 00:11:29
# BGP session reset suspected for peer 9902 between 2023-01-01 00:11:29 and 2023-01-01 00:12:30
# BGP session reset suspected for peer 9902 between 2023-01-01 00:12:30 and 2023-01-01 00:13:31
# BGP session reset suspected for peer 9902 between 2023-01-01 00:13:31 and 2023-01-01 00:14:32
# BGP session reset suspected for peer 9902 between 2023-01-01 00:14:32 and 2023-01-01 00:15:33
# BGP session reset suspected for peer 9902 between 2023-01-01 00:15:33 and 2023-01-01 00:16:37
# BGP session reset suspected for peer 9902 between 2023-01-01 00:16:37 and 2023-01-01 00:17:41
# BGP session reset suspected for peer 9902 between 2023-01-01 00:17:41 and 2023-01-01 00:18:42
# BGP session reset suspected for peer 9902 between 2023-01-01 00:18:42 and 2023-01-01 00:19:43
# BGP session reset suspected for peer 9902 between 2023-01-01 00:19:43 and 2023-01-01 00:20:47
# BGP session reset suspected for peer 9902 between 2023-01-01 00:20:47 and 2023-01-01 00:21:50
# BGP session reset suspected for peer 9902 between 2023-01-01 00:21:50 and 2023-01-01 00:22:53
# BGP session reset suspected for peer 9902 between 2023-01-01 00:22:53 and 2023-01-01 00:23:58
# BGP session reset suspected for peer 9902 between 2023-01-01 00:23:58 and 2023-01-01 00:25:03
# BGP session reset suspected for peer 9902 between 2023-01-01 00:25:03 and 2023-01-01 00:26:06
# BGP session reset suspected for peer 9902 between 2023-01-01 00:26:06 and 2023-01-01 00:27:08
# BGP session reset suspected for peer 9902 between 2023-01-01 00:27:08 and 2023-01-01 00:28:13
# BGP session reset suspected for peer 9902 between 2023-01-01 00:28:13 and 2023-01-01 00:29:14
# BGP session reset suspected for peer 9902 between 2023-01-01 00:29:14 and 2023-01-01 00:30:17
# BGP session reset suspected for peer 9902 between 2023-01-01 00:30:17 and 2023-01-01 00:31:18
# BGP session reset suspected for peer 9902 between 2023-01-01 00:31:18 and 2023-01-01 00:32:20
# BGP session reset suspected for peer 9902 between 2023-01-01 00:32:20 and 2023-01-01 00:33:23
# BGP session reset suspected for peer 9902 between 2023-01-01 00:33:23 and 2023-01-01 00:34:26
# BGP session reset suspected for peer 9902 between 2023-01-01 00:34:26 and 2023-01-01 00:35:28
# BGP session reset suspected for peer 9902 between 2023-01-01 00:35:28 and 2023-01-01 00:36:30
# BGP session reset suspected for peer 9902 between 2023-01-01 00:36:30 and 2023-01-01 00:37:35
# BGP session reset suspected for peer 9902 between 2023-01-01 00:37:35 and 2023-01-01 00:38:40
# BGP session reset suspected for peer 9902 between 2023-01-01 00:38:40 and 2023-01-01 00:39:44
# BGP session reset suspected for peer 9902 between 2023-01-01 00:39:44 and 2023-01-01 00:40:45
# BGP session reset suspected for peer 9902 between 2023-01-01 00:40:45 and 2023-01-01 00:41:46
# BGP session reset suspected for peer 9902 between 2023-01-01 00:41:46 and 2023-01-01 00:42:50
# BGP session reset suspected for peer 9902 between 2023-01-01 00:42:50 and 2023-01-01 00:43:52
# BGP session reset suspected for peer 9902 between 2023-01-01 00:43:52 and 2023-01-01 00:44:55
# BGP session reset suspected for peer 9902 between 2023-01-01 00:44:55 and 2023-01-01 00:46:00
# BGP session reset suspected for peer 9902 between 2023-01-01 00:46:00 and 2023-01-01 00:47:03
# BGP session reset suspected for peer 9902 between 2023-01-01 00:47:03 and 2023-01-01 00:48:05
# BGP session reset suspected for peer 9902 between 2023-01-01 00:48:05 and 2023-01-01 00:49:10
# BGP session reset suspected for peer 9902 between 2023-01-01 00:49:10 and 2023-01-01 00:50:11
# BGP session reset suspected for peer 9902 between 2023-01-01 00:50:11 and 2023-01-01 00:51:15
# BGP session reset suspected for peer 9902 between 2023-01-01 00:51:15 and 2023-01-01 00:52:16
# BGP session reset suspected for peer 9902 between 2023-01-01 00:52:16 and 2023-01-01 00:53:17
# BGP session reset suspected for peer 9902 between 2023-01-01 00:53:17 and 2023-01-01 00:54:18
# BGP session reset suspected for peer 9902 between 2023-01-01 00:54:18 and 2023-01-01 00:55:20
# BGP session reset suspected for peer 9902 between 2023-01-01 00:55:20 and 2023-01-01 00:56:21
# BGP session reset suspected for peer 9902 between 2023-01-01 00:56:21 and 2023-01-01 00:57:22
# BGP session reset suspected for peer 9902 between 2023-01-01 00:57:22 and 2023-01-01 00:58:23
# BGP session reset suspected for peer 9902 between 2023-01-01 00:58:23 and 2023-01-01 00:59:28
# BGP session reset suspected for peer 9902 between 2023-01-01 00:59:28 and 2023-01-01 01:00:29
# BGP session reset suspected for peer 9902 between 2023-01-01 01:00:29 and 2023-01-01 01:01:31
# BGP session reset suspected for peer 9902 between 2023-01-01 01:01:31 and 2023-01-01 01:02:33
# BGP session reset suspected for peer 9902 between 2023-01-01 01:02:33 and 2023-01-01 01:03:35
# BGP session reset suspected for peer 9902 between 2023-01-01 01:03:35 and 2023-01-01 01:04:37
# BGP session reset suspected for peer 9902 between 2023-01-01 02:46:53 and 2023-01-01 02:47:57
# BGP session reset suspected for peer 9902 between 2023-01-01 02:47:57 and 2023-01-01 02:48:58
# BGP session reset suspected for peer 9902 between 2023-01-01 02:48:58 and 2023-01-01 02:50:00
# BGP session reset suspected for peer 9902 between 2023-01-01 02:50:00 and 2023-01-01 02:51:03
# BGP session reset suspected for peer 9902 between 2023-01-01 02:51:03 and 2023-01-01 02:52:04
# BGP session reset suspected for peer 9902 between 2023-01-01 02:52:04 and 2023-01-01 02:53:05
# BGP session reset suspected for peer 9902 between 2023-01-01 02:53:05 and 2023-01-01 02:54:07
# BGP session reset suspected for peer 9902 between 2023-01-01 02:54:07 and 2023-01-01 02:55:09
# BGP session reset suspected for peer 9902 between 2023-01-01 02:55:09 and 2023-01-01 02:56:11
# BGP session reset suspected for peer 9902 between 2023-01-01 02:56:11 and 2023-01-01 02:57:13
# BGP session reset suspected for peer 9902 between 2023-01-01 02:57:13 and 2023-01-01 02:58:15
# BGP session reset suspected for peer 9902 between 2023-01-01 02:58:15 and 2023-01-01 02:59:16
# BGP session reset suspected for peer 7713 between 2023-01-01 00:00:11 and 2023-01-01 00:01:13
# BGP session reset suspected for peer 7713 between 2023-01-01 00:01:13 and 2023-01-01 00:02:14
# BGP session reset suspected for peer 7713 between 2023-01-01 00:02:14 and 2023-01-01 00:03:18
# BGP session reset suspected for peer 7713 between 2023-01-01 00:03:18 and 2023-01-01 00:04:22
# BGP session reset suspected for peer 7713 between 2023-01-01 00:04:22 and 2023-01-01 00:05:26
# BGP session reset suspected for peer 7713 between 2023-01-01 00:05:26 and 2023-01-01 00:06:28
# BGP session reset suspected for peer 7713 between 2023-01-01 00:06:28 and 2023-01-01 00:07:32
# BGP session reset suspected for peer 7713 between 2023-01-01 00:07:32 and 2023-01-01 00:08:37
# BGP session reset suspected for peer 7713 between 2023-01-01 00:08:37 and 2023-01-01 00:09:40
# BGP session reset suspected for peer 7713 between 2023-01-01 00:09:40 and 2023-01-01 00:10:42
# BGP session reset suspected for peer 7713 between 2023-01-01 00:10:42 and 2023-01-01 00:11:45
# BGP session reset suspected for peer 7713 between 2023-01-01 00:11:45 and 2023-01-01 00:12:47
# BGP session reset suspected for peer 7713 between 2023-01-01 00:12:47 and 2023-01-01 00:13:49
# BGP session reset suspected for peer 7713 between 2023-01-01 00:13:49 and 2023-01-01 00:14:53
# BGP session reset suspected for peer 7713 between 2023-01-01 00:14:53 and 2023-01-01 00:15:56
# BGP session reset suspected for peer 7713 between 2023-01-01 00:15:56 and 2023-01-01 00:17:15
# BGP session reset suspected for peer 7713 between 2023-01-01 00:17:15 and 2023-01-01 00:18:22
# BGP session reset suspected for peer 7713 between 2023-01-01 00:18:22 and 2023-01-01 00:19:29
# BGP session reset suspected for peer 7713 between 2023-01-01 00:19:29 and 2023-01-01 00:20:34
# BGP session reset suspected for peer 7713 between 2023-01-01 00:20:34 and 2023-01-01 00:21:39
# BGP session reset suspected for peer 7713 between 2023-01-01 00:21:39 and 2023-01-01 00:22:42
# BGP session reset suspected for peer 7713 between 2023-01-01 00:22:42 and 2023-01-01 00:23:46
# BGP session reset suspected for peer 7713 between 2023-01-01 00:23:46 and 2023-01-01 00:25:00
# BGP session reset suspected for peer 7713 between 2023-01-01 00:25:00 and 2023-01-01 00:26:05
# BGP session reset suspected for peer 7713 between 2023-01-01 00:26:05 and 2023-01-01 00:27:07
# BGP session reset suspected for peer 7713 between 2023-01-01 00:27:07 and 2023-01-01 00:28:09
# BGP session reset suspected for peer 7713 between 2023-01-01 00:28:09 and 2023-01-01 00:29:14
# BGP session reset suspected for peer 7713 between 2023-01-01 00:29:14 and 2023-01-01 00:30:15
# BGP session reset suspected for peer 7713 between 2023-01-01 00:30:15 and 2023-01-01 00:31:19
# BGP session reset suspected for peer 7713 between 2023-01-01 00:31:19 and 2023-01-01 00:32:25
# BGP session reset suspected for peer 7713 between 2023-01-01 00:32:25 and 2023-01-01 00:33:31
# BGP session reset suspected for peer 7713 between 2023-01-01 00:33:31 and 2023-01-01 00:34:38
# BGP session reset suspected for peer 7713 between 2023-01-01 00:34:38 and 2023-01-01 00:35:40
# BGP session reset suspected for peer 7713 between 2023-01-01 00:35:40 and 2023-01-01 00:36:46
# BGP session reset suspected for peer 7713 between 2023-01-01 00:36:46 and 2023-01-01 00:37:50
# BGP session reset suspected for peer 7713 between 2023-01-01 00:37:50 and 2023-01-01 00:38:55
# BGP session reset suspected for peer 7713 between 2023-01-01 00:38:55 and 2023-01-01 00:39:58
# BGP session reset suspected for peer 7713 between 2023-01-01 00:39:58 and 2023-01-01 00:41:00
# BGP session reset suspected for peer 7713 between 2023-01-01 00:41:00 and 2023-01-01 00:42:03
# BGP session reset suspected for peer 7713 between 2023-01-01 00:42:03 and 2023-01-01 00:43:06
# BGP session reset suspected for peer 7713 between 2023-01-01 00:43:06 and 2023-01-01 00:44:09
# BGP session reset suspected for peer 7713 between 2023-01-01 00:44:09 and 2023-01-01 00:45:10
# BGP session reset suspected for peer 7713 between 2023-01-01 00:45:10 and 2023-01-01 00:46:15
# BGP session reset suspected for peer 7713 between 2023-01-01 00:46:15 and 2023-01-01 00:47:23
# BGP session reset suspected for peer 7713 between 2023-01-01 00:47:23 and 2023-01-01 00:48:29
# BGP session reset suspected for peer 7713 between 2023-01-01 00:48:29 and 2023-01-01 00:49:32
# BGP session reset suspected for peer 7713 between 2023-01-01 00:49:32 and 2023-01-01 00:50:37
# BGP session reset suspected for peer 7713 between 2023-01-01 00:50:37 and 2023-01-01 00:51:43
# BGP session reset suspected for peer 7713 between 2023-01-01 00:51:43 and 2023-01-01 00:52:47
# BGP session reset suspected for peer 7713 between 2023-01-01 00:52:47 and 2023-01-01 00:53:51
# BGP session reset suspected for peer 7713 between 2023-01-01 00:53:51 and 2023-01-01 00:54:59
# BGP session reset suspected for peer 7713 between 2023-01-01 00:54:59 and 2023-01-01 00:56:03
# BGP session reset suspected for peer 7713 between 2023-01-01 00:56:03 and 2023-01-01 00:57:07
# {'peer_asn': 16509, 'start_time': '2023-01-01T02:50:01', 'end_time': '2023-01-01T02:54:30', 'withdrawal_count': 6}
# {'peer_asn': 59318, 'start_time': '2023-01-01T00:12:41', 'end_time': '2023-01-01T00:13:57', 'withdrawal_count': 6}
# {'peer_asn': 59318, 'start_time': '2023-01-01T00:30:12', 'end_time': '2023-01-01T00:31:25', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T00:34:04', 'end_time': '2023-01-01T00:35:11', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T00:52:39', 'end_time': '2023-01-01T00:53:59', 'withdrawal_count': 6}
# {'peer_asn': 59318, 'start_time': '2023-01-01T01:12:11', 'end_time': '2023-01-01T01:15:15', 'withdrawal_count': 6}
# {'peer_asn': 59318, 'start_time': '2023-01-01T01:25:45', 'end_time': '2023-01-01T01:27:20', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T01:32:25', 'end_time': '2023-01-01T01:33:26', 'withdrawal_count': 7}
# {'peer_asn': 59318, 'start_time': '2023-01-01T01:51:30', 'end_time': '2023-01-01T01:52:50', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:06:22', 'end_time': '2023-01-01T02:08:33', 'withdrawal_count': 10}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:11:10', 'end_time': '2023-01-01T02:13:46', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:31:32', 'end_time': '2023-01-01T02:33:37', 'withdrawal_count': 7}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:40:27', 'end_time': '2023-01-01T02:45:41', 'withdrawal_count': 6}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:45:41', 'end_time': '2023-01-01T02:46:42', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:50:32', 'end_time': '2023-01-01T02:51:40', 'withdrawal_count': 5}
# {'peer_asn': 59318, 'start_time': '2023-01-01T02:52:52', 'end_time': '2023-01-01T02:54:34', 'withdrawal_count': 6}

# %% [markdown]
# # Analyzing Convergence Times

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def analyze_convergence_times(from_time, until_time, target_prefixes=None, collectors=['route-views.sg']):
    """
    Analyzes BGP convergence times for prefix updates.

    :param from_time: Start time for data collection.
    :param until_time: End time for data collection.
    :param target_prefixes: List of prefixes to analyze; if None, analyze all prefixes.
    :param collectors: List of collectors to use.
    """
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    prefix_update_times = defaultdict(list)

    for rec in stream.records():
        for elem in rec:
            prefix = elem.fields.get("prefix")
            if prefix is None:
                continue

            if target_prefixes and prefix not in target_prefixes:
                continue

            timestamp = elem.time
            prefix_update_times[prefix].append(timestamp)

    # Calculate convergence times
    for prefix, times in prefix_update_times.items():
        first_time = min(times)
        last_time = max(times)
        convergence_time = last_time - first_time
        print(f"Prefix {prefix} convergence time: {convergence_time} seconds")

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 01:00:00"
target_prefixes = ['192.0.2.0/24']
analyze_convergence_times(from_time, until_time, target_prefixes)

# %% [markdown]
# # Detecting BGP Route Leaks

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

# Simplified relationships for illustration purposes
AS_RELATIONSHIPS = {
    '64500': {'providers': ['64501'], 'customers': ['64502']},
    '64501': {'providers': [], 'customers': ['64500']},
    '64502': {'providers': ['64500'], 'customers': []},
    # Add more AS relationships as needed
}

def is_route_leak(as_path):
    """
    Detects if an AS path indicates a route leak based on simplified relationships.

    :param as_path: List of ASNs in the AS path.
    :return: True if a route leak is detected, False otherwise.
    """
    for i in range(len(as_path) - 1):
        asn_current = as_path[i]
        asn_next = as_path[i + 1]
        relationships = AS_RELATIONSHIPS.get(asn_current, {})
        if asn_next in relationships.get('providers', []):
            # Route leak detected: customer announcing to provider
            return True
    return False

def detect_route_leaks(from_time, until_time, collectors=['route-views.sg']):
    """
    Detects potential BGP route leaks.

    :param from_time: Start time for data collection.
    :param until_time: End time for data collection.
    :param collectors: List of collectors to use.
    """
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    route_leak_events = []

    for rec in stream.records():
        for elem in rec:
            if elem.type != 'A':
                continue

            as_path_str = elem.fields.get('as-path', "")
            as_path = as_path_str.split()

            if not as_path or len(as_path) < 2:
                continue

            if is_route_leak(as_path):
                event = {
                    'timestamp': datetime.utcfromtimestamp(elem.time).isoformat(),
                    'as_path': as_path_str,
                    'collector': rec.collector
                }
                route_leak_events.append(event)
                print(f"Potential route leak detected: AS path {as_path_str}")

    # Output route leak events
    print("\nRoute Leak Events:")
    for event in route_leak_events:
        print(event)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 03:00:00"
detect_route_leaks(from_time, until_time)
# Out:
# Route Leak Events:

# %% [markdown]
# # Monitoring Updates for Specific ASNs

# %%
import pybgpstream
from collections import defaultdict
from datetime import datetime

def monitor_updates_for_asns(from_time, until_time, target_asns, collectors=['route-views.sg']):
    target_asns = set(str(asn) for asn in target_asns)
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    updates_involving_asns = []

    for rec in stream.records():
        for elem in rec:
            as_path_str = elem.fields.get('as-path', "")
            as_path = as_path_str.split()

            if not as_path:
                continue

            if target_asns.intersection(as_path):
                update = {
                    'timestamp': datetime.utcfromtimestamp(elem.time).isoformat(),
                    'as_path': as_path_str,
                    'prefix': elem.fields.get("prefix"),
                    'type': elem.type,
                    'collector': rec.collector
                }
                updates_involving_asns.append(update)
                print(f"Update involving target ASN(s): {update}")

    # Output collected updates
    print("\nUpdates Involving Target ASNs:")
    for update in updates_involving_asns:
        print(update)

# Usage
from_time = "2023-01-01 00:00:00"
until_time = "2023-01-01 02:00:00"
target_asns = ['64500', '64501']
monitor_updates_for_asns(from_time, until_time, target_asns)
